# %%
import time
import ee
ee.Initialize()
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# 2021.03.18_SSURGO_extraction.ipynb
# 2021.03.19_ssurgo_variables_full
# 2021.03.19_ssurgo_variables_full.csv
# 2021.04.02_ssurgo_cwr_nwpr_variables_full
# 2021_03_06_SSURGO_extraction.ipynb
# SSURGO_combined_regular_clean_with_ssurgo_variables_updated.csv
# cwr_nwpr_dataset
# gNATSGO-mukey (1).tif
# muaggatt.txt
# muaggatt.zip

# %%
# SSURGO look up table
df_mukey = pd.read_csv("muaggatt.txt", delimiter = "\t")
df_mukey.columns
# Out:
# /Users/Madhukar/opt/miniconda3/envs/ee/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['musym', 'muname', 'mustatus', 'slopegradd', 'slopegradw', 'brockdepmi',
#        'wtdepannmi', 'wtdepaprju', 'flodfreqdc', 'flodfreqma', 'pondfreqpr',
#        'aws025wta', 'aws050wta', 'aws0100wta', 'aws0150wta', 'drclassdcd',
#        'drclasswet', 'hydgrpdcd', 'iccdcd', 'iccdcdpct', 'niccdcd',
#        'niccdcdpct', 'engdwobdcd', 'engdwbdcd', 'engdwbll', 'engdwbml',
#        'engstafdcd', 'engstafll', 'engstafml', 'engsldcd', 'engsldcp',
#        'englrsdcd', 'engcmssdcd', 'engcmssmp', 'urbrecptdc', 'urbrecptwt',
#        'forpehrtdc', 'hydclprs', 'awmmfpwwta', 'mukey'],
#       dtype='object')

# %%
# df = pd.read_csv("SSURGO_combined_regular_clean_with_ssurgo_variables_updated.csv")
df = pd.read_pickle("cwr_nwpr_dataset")
df.columns
# Out:
# Index(['jurisdiction_type', 'da_number', 'latitude', 'longitude',
#        'cwa_determination', 'Index'],
#       dtype='object')

# %%
df[df.da_number == "SAW-2004-00943"].iloc[:,10:26]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# isolated_waters_but_protected = (df[df.cwa1 + df.cwa2 + df.cwa3 + df.cwa4 
#     + df.cwa5 + df.cwa6 + df.cwa7 + df.cwa8==0]
#  [df.cwa9==1]
#  [df.cwa_determination==1]).shape[0]

# print("cwa9 = 1 and cwa_determination == 1:", isolated_waters_but_protected)

# isolated_waters_but_unprotected = (df[df.cwa1 + df.cwa2 + df.cwa3 + df.cwa4 
#     + df.cwa5 + df.cwa6 + df.cwa7 + df.cwa8==0]
#  [df.cwa9==1]
#  [df.cwa_determination==0]).shape[0]

# print("cwa9 = 1 and cwa_determination != 1:", isolated_waters_but_unprotected)

# %%
def find_mukey(lat=None, lon=None):
  ssurgo = ee.Image("users/madhukarreddy/gSSURGO")
  pt = ee.Geometry.Point([lon, lat])
  try:
    mukey = ssurgo.select('b1').clip(pt).sample(pt).getInfo()["features"][0]['properties']['b1'] 
    return mukey
  except Exception as e:
    print(e)
    return np.nan
  
# lat = float(df[df.index == 100].latitude)
# lon = float(df[df.index == 100].longitude)
find_mukey(37.4811, -121.9641) # this is known wetland, so should read 100%
# Out:
# 456691

# %%
def find_feature_from_mukey(feature, mukey):
    if not np.isnan(mukey):
        feature_value = df_mukey[df_mukey["mukey"] == mukey][feature]
#         return feature_value#.mean()
        feature_value = np.array(feature_value)
        return feature_value[0]

    else:
        return np.nan
        # return np.array(np.nan)

# %%
find_feature_from_mukey("hydclprs", 456691)
# Out:
# 100

# %%
for feature in df_mukey.columns:
    if df_mukey[feature].dtypes == 'object':
        print(feature, ":", len(df_mukey[feature].unique()), df_mukey[feature].unique())
        print()
# Out:
# musym : 49892 ['1030' '1033' '1059' ... '2qgvm' '2qgvn' '2qgvp']
#
# muname : 167077 ['Udorthents-Pits, gravel complex' 'Beaches-Menahga complex'
#  'Wega silt loam' ... 'Raster map unit 22N, 8 to 15 percent slopes'
#  'Raster map unit 32N, 8 to 15 percent slopes'
#  'Raster map unit 33N, 15 to 25 percent slopes']
#
# mustatus : 3 [nan 'Provisional' 'Correlated']
#
# flodfreqdc : 8 ['None' nan 'Rare' 'Occasional' 'Frequent' 'Very frequent' 'Very rare'
#  'Common']
#
# flodfreqma : 8 ['None' 'Rare' 'Occasional' 'Frequent' nan 'Very frequent' 'Very rare'
#  'Common']
#
# drclassdcd : 9 ['Well drained' nan 'Somewhat poorly drained' 'Poorly drained'
#  'Moderately well drained' 'Very poorly drained' 'Excessively drained'
#  'Somewhat excessively drained' 'Subaqueous']
#
# drclasswet : 9 ['Well drained' 'Excessively drained' 'Somewhat poorly drained'
#  'Moderately well drained' 'Poorly drained' 'Very poorly drained'
#  'Somewhat excessively drained' nan 'Subaqueous']
#
# ...

# %%
imp_ssurgo_cols = ['mustatus', 'slopegradd', 'slopegradw', 'brockdepmi',
       'wtdepannmi', 'wtdepaprju', 'flodfreqdc', 'flodfreqma', 'pondfreqpr',
       'aws025wta', 'aws050wta', 'aws0100wta', 'aws0150wta', 'drclassdcd',
       'drclasswet', 'hydgrpdcd', 'iccdcd', 'iccdcdpct', 'niccdcd',
       'niccdcdpct', 'engdwobdcd', 'engdwbdcd', 'engdwbll', 'engdwbml',
       'engstafdcd', 'engstafll', 'engstafml', 'engsldcd', 'engsldcp',
       'englrsdcd', 'engcmssdcd', 'engcmssmp', 'urbrecptdc', 'urbrecptwt',
       'forpehrtdc', 'hydclprs', 'awmmfpwwta', 'mukey']

# %%
df.columns
# Out:
# Index(['jurisdiction_type', 'da_number', 'latitude', 'longitude',
#        'cwa_determination', 'Index'],
#       dtype='object')

# %%
# df = df[["Index", "mukey", 'longitude', 'latitude']] 

for col in imp_ssurgo_cols:
    df[col] = df.apply(lambda x: find_feature_from_mukey(col, find_mukey(x.latitude, x.longitude)), axis=1)
# Out:
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# ...

# %%
# df = df[["Index", "mukey", 'longitude', 'latitude']] 

# for col in imp_ssurgo_cols:
#     df[col] = df.apply(lambda x: find_feature_from_mukey(col, x.mukey), axis=1)

# %%
df.columns
# Out:
# Index(['jurisdiction_type', 'da_number', 'latitude', 'longitude',
#        'cwa_determination', 'Index', 'mustatus', 'slopegradd', 'slopegradw',
#        'brockdepmi', 'wtdepannmi', 'wtdepaprju', 'flodfreqdc', 'flodfreqma',
#        'pondfreqpr', 'aws025wta', 'aws050wta', 'aws0100wta', 'aws0150wta',
#        'drclassdcd', 'drclasswet', 'hydgrpdcd', 'iccdcd', 'iccdcdpct',
#        'niccdcd', 'niccdcdpct', 'engdwobdcd', 'engdwbdcd', 'engdwbll',
#        'engdwbml', 'engstafdcd', 'engstafll', 'engstafml', 'engsldcd',
#        'engsldcp', 'englrsdcd', 'engcmssdcd', 'engcmssmp', 'urbrecptdc',
#        'urbrecptwt', 'forpehrtdc', 'hydclprs', 'awmmfpwwta', 'mukey'],
#       dtype='object')

# %%
import pickle

# use protocol 3 for backwards compatibility with Python 3.6 on AWS
pickle.dump(df, open("2021.04.02_ssurgo_cwr_nwpr_variables_full","wb"), protocol=3)
# df.to_csv("2021.03.19_ssurgo_variables_full.csv")

# %%
df = pd.read_pickle("2021.04.02_ssurgo_cwr_nwpr_variables_full")

# %%
# df.mustatus.unique()

# %%
df.columns
# Out:
# Index(['jurisdiction_type', 'da_number', 'latitude', 'longitude',
#        'cwa_determination', 'Index', 'mustatus', 'slopegradd', 'slopegradw',
#        'brockdepmi', 'wtdepannmi', 'wtdepaprju', 'flodfreqdc', 'flodfreqma',
#        'pondfreqpr', 'aws025wta', 'aws050wta', 'aws0100wta', 'aws0150wta',
#        'drclassdcd', 'drclasswet', 'hydgrpdcd', 'iccdcd', 'iccdcdpct',
#        'niccdcd', 'niccdcdpct', 'engdwobdcd', 'engdwbdcd', 'engdwbll',
#        'engdwbml', 'engstafdcd', 'engstafll', 'engstafml', 'engsldcd',
#        'engsldcp', 'englrsdcd', 'engcmssdcd', 'engcmssmp', 'urbrecptdc',
#        'urbrecptwt', 'forpehrtdc', 'hydclprs', 'awmmfpwwta', 'mukey'],
#       dtype='object')

# %%
df[['Index', 'wtdepannmi', 'slopegradd', 'slopegradw', 'brockdepmi', 'wtdepannmi', 'wtdepaprju', 'flodfreqdc','flodfreqma', 'pondfreqpr', 'aws025wta', 'aws050wta', 'aws0100wta']]
# Out:
#        Index  wtdepannmi  slopegradd  slopegradw  brockdepmi  wtdepannmi  \
# 14324      1         0.0         6.0         6.0         0.0         0.0
# 14339      2         0.0         3.0         3.9         0.0         0.0
# 14346      3         0.0         5.0         5.0         0.0         0.0
# 14348      4        84.0         0.5         0.5         0.0        84.0
# 14378      5         0.0         1.0         1.0         0.0         0.0
# ...      ...         ...         ...         ...         ...         ...
# 7258    3214        15.0         2.0         2.0         0.0        15.0
# 7262    3215        15.0         0.5         0.5         0.0        15.0
# 7266    3216        50.0         1.5         1.6         0.0        50.0
# 7272    3217        15.0         0.5         0.5         0.0        15.0
# 7273    3218         0.0         1.0         1.1         0.0         0.0
#
#        wtdepaprju flodfreqdc flodfreqma  pondfreqpr  aws025wta  aws050wta  \
# ...

# %%
num = df.describe().columns
num
# Out:
# Index(['latitude', 'longitude', 'Index', 'slopegradd', 'slopegradw',
#        'brockdepmi', 'wtdepannmi', 'wtdepaprju', 'pondfreqpr', 'aws025wta',
#        'aws050wta', 'aws0100wta', 'aws0150wta', 'iccdcd', 'iccdcdpct',
#        'niccdcd', 'niccdcdpct', 'urbrecptwt', 'hydclprs', 'awmmfpwwta',
#        'mukey'],
#       dtype='object')

# %%
df[num]
# Out:
#        latitude  longitude  Index  slopegradd  slopegradw  brockdepmi  \
# 14324  32.56200 -117.02018      1         6.0         6.0         0.0
# 14339  38.92073  -77.14066      2         3.0         3.9         0.0
# 14346  38.84361  -77.07721      3         5.0         5.0         0.0
# 14348  41.99860  -87.92959      4         0.5         0.5         0.0
# 14378  47.38801  -93.43970      5         1.0         1.0         0.0
# ...         ...        ...    ...         ...         ...         ...
# 7258   42.49676  -87.88936   3214         2.0         2.0         0.0
# 7262   42.56629  -87.93757   3215         0.5         0.5         0.0
# 7266   42.80008  -87.78949   3216         1.5         1.6         0.0
# 7272   42.96569  -88.09611   3217         0.5         0.5         0.0
# 7273   44.20724  -94.14484   3218         1.0         1.1         0.0
#
#        wtdepannmi  wtdepaprju  pondfreqpr  aws025wta  ...  aws0100wta  \
# ...

# %%
for col in num:
    print(col, np.mean(df[col].isna()))
    print()
# Out:
# latitude 0.0
#
# longitude 0.0
#
# Index 0.0
#
# slopegradd 0.020820385332504663
#
# slopegradw 0.020820385332504663
#
# brockdepmi 0.020820385332504663
#
# wtdepannmi 0.020820385332504663
#
# wtdepaprju 0.020820385332504663
#
# pondfreqpr 0.020820385332504663
#
# aws025wta 0.020820385332504663
#
# aws050wta 0.020820385332504663
#
# aws0100wta 0.020820385332504663
#
# aws0150wta 0.020820385332504663
#
# iccdcd 0.8862647607209447
#
# iccdcdpct 0.020820385332504663
#
# niccdcd 0.06836544437538844
#
# niccdcdpct 0.020820385332504663
#
# urbrecptwt 0.020820385332504663
#
# hydclprs 0.020820385332504663
#
# awmmfpwwta 0.020820385332504663
#
# mukey 0.020820385332504663

# %%
cat = set(df.columns) - set(num)
cat
# Out:
# {'cwa_determination',
#  'da_number',
#  'drclassdcd',
#  'drclasswet',
#  'engcmssdcd',
#  'engcmssmp',
#  'engdwbdcd',
#  'engdwbll',
#  'engdwbml',
#  'engdwobdcd',
#  'englrsdcd',
#  'engsldcd',
#  'engsldcp',
#  'engstafdcd',
#  'engstafll',
#  'engstafml',
#  'flodfreqdc',
#  'flodfreqma',
#  'forpehrtdc',
#  'hydgrpdcd',
#  'jurisdiction_type',
#  'mustatus',
#  'urbrecptdc'}

# %%
for col in cat:
    print(col, df[col].unique())
    print()
# Out:
# hydgrpdcd ['D' 'C' nan 'C/D' 'A/D' 'B/D' 'B' 'A']
#
# engsldcp ['Very limited' 'Somewhat limited' 'Not rated' 'Not limited' nan]
#
# engstafml ['Very limited' 'Not rated' 'Somewhat limited' nan 'Not limited']
#
# flodfreqdc ['None' 'Occasional' nan 'Frequent' 'Very frequent' 'Rare' 'Very rare']
#
# engsldcd ['Very limited' 'Somewhat limited' 'Not rated' 'Not limited' nan]
#
# cwa_determination [1 '0']
#
# engdwbdcd ['Somewhat limited' 'Not limited' 'Not rated' 'Very limited' nan]
#
# forpehrtdc ['Slight' 'Moderate' 'Not rated' 'Severe' nan]
#
# da_number ['SPL-2015-00294' 'NAO-2019-02292' 'NAO-2019-00266' ... 'MVP-2020-00788'
#  'MVP-2020-01031' 'MVP-2019-00129']
#
# engdwbll ['Not rated' 'Not limited' 'Somewhat limited' 'Very limited' nan]
#
# drclasswet ['Well drained' nan 'Moderately well drained' 'Somewhat poorly drained'
#  'Very poorly drained' 'Poorly drained' 'Somewhat excessively drained'
#  'Excessively drained' 'Subaqueous']
#
# ...

# %%
df
# Out:
#       jurisdiction_type       da_number  latitude  longitude  \
# 14324               CWR  SPL-2015-00294  32.56200 -117.02018
# 14339               CWR  NAO-2019-02292  38.92073  -77.14066
# 14346               CWR  NAO-2019-00266  38.84361  -77.07721
# 14348               CWR  LRC-2003-22401  41.99860  -87.92959
# 14378               CWR  MVP-2019-00125  47.38801  -93.43970
# ...                 ...             ...       ...        ...
# 7258               NWPR  MVP-2020-00174  42.49676  -87.88936
# 7262               NWPR  MVP-2019-00455  42.56629  -87.93757
# 7266               NWPR  MVP-2020-00788  42.80008  -87.78949
# 7272               NWPR  MVP-2020-01031  42.96569  -88.09611
# 7273               NWPR  MVP-2019-00129  44.20724  -94.14484
#
#       cwa_determination  Index mustatus  slopegradd  slopegradw  brockdepmi  \
# 14324                 1      1      NaN         6.0         6.0         0.0
# 14339                 1      2      NaN         3.0         3.9         0.0
# ...
