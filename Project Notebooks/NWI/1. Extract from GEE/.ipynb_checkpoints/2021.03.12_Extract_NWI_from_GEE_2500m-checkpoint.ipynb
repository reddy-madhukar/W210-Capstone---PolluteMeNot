# %% [markdown]
# # Notebook to extract variables out of NHD database

# %% [markdown]
# Originally 2021.02.23_ExportImagestoGCS_MR1_Copy.ipynb

# %% [markdown]
# # Authentications

# %%
import pandas as pd
import numpy as np
import time
import ee
import pickle
ee.Initialize()

# %% [markdown]
# # Patch Size

# %%
PATCH_SIZE = 1250 # 100 or 1250

# %% [markdown]
# # Set up bounding box

# %%
def square(lat, lon, size):
  crs_proj = "EPSG:4326"  
  return ee.Geometry.Point([lon, lat], proj=crs_proj).buffer(size).bounds()

# %%
full_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

no_data_states = ["LA", "MD", "SC"]

states = list(set(full_states) - set(no_data_states))

# %% [markdown]
# # NWI

# %%
merged = ee.FeatureCollection([None])

state_dict = {"AK" : ["North", "Central", "South"],
             "CA" : ["North", "NorthCentral", "South", "SouthCentral"],
             "WI" : ["North", "South"],
             "CO" : ["East", "West"],
             "IA" : ["East", "West"],
             "KS" : ["East", "West"],
             "MN" : ["Central_West", "East", "North_Central", "North_East", "North_West", "South"],
             "MT" : ["East", "West"],
             "ND" : ["East", "West"],
             "NE" : ["East", "West"],
             "NV" : ["North", "South"],
             "OK" : ["East", "West"],
             "OR" : ["East", "West"],
             "SD" : ["East", "West"],
             "TX" : ["East", "West", "Central"],
             "WI" : ["North", "South"],
             "WY" : ["East", "West"]}

for state in states:
    directions_list = state_dict.get(state)
    if directions_list == None:
        merged = merged.merge(ee.FeatureCollection("users/madhukarreddy/NWI_" + state +"_Wetlands"))
    else:
        for direction in directions_list:
            merged = (merged.merge(ee.FeatureCollection("users/madhukarreddy/NWI_" + 
                                                        state +  
                                                        "_Wetlands" + "_" + 
                                                        direction )))
fc = merged

# %%
# fc.getInfo()

# %%
# fc_getInfo = fc.filterBounds(square(lat=45.475649, lon=-69.471018 , size=PATCH_SIZE)).getInfo()
# fc_getInfo = fc_getInfo.get('features')
# num_of_features = len(fc_getInfo)
# print("number of features =", num_of_features)

# attr_list = []
# wetland_list = []
# for feature in range(num_of_features):
#     # some features are described as "PSS3/EM1E"
#     # split them out so each attritube can be joined to the wetland defns csv
#     attr_element = fc_getInfo[feature].get('properties').get('ATTRIBUTE').split("/")
#     [attr_list.append(element) for element in attr_element]
# #     attr_list.append(fc_getInfo[feature].get('properties').get('ATTRIBUTE'))

#     wetland_element = fc_getInfo[feature].get('properties').get('WETLAND_TY').split("/")
#     [wetland_list.append(element) for element in wetland_element]
# #     wetland_list.append(fc_getInfo[feature].get('properties').get('WETLAND_TY'))


# print(attr_list)
# print(wetland_list)

# %%
def nwi_bbox_features(lat=45.475649, lon=-69.471018 , size=PATCH_SIZE):
    """
    input: lat, lon, and size=half of bbox side
    output:
        - num_of_features: number of NWI features intersected by bbox
        - attr_list: list of NWI attributes for wetland types
        - wetland_list: WETLAND_TY for each ATTRIBUTE
    """
    try:
        fc_getInfo = fc.filterBounds(square(lat, lon, size)).getInfo()
        fc_getInfo = fc_getInfo.get('features')
        num_of_features = len(fc_getInfo)
        print("number of features =", num_of_features)

        attr_list = []
        wetland_list = []
        for feature in range(num_of_features):

            # some features are described as "PSS3/EM1E"
            # split them out so each attritube can be joined to the wetland defns csv
            attr_element = fc_getInfo[feature].get('properties').get('ATTRIBUTE').split("/")
            [attr_list.append(element) for element in attr_element]

            wetland_element = fc_getInfo[feature].get('properties').get('WETLAND_TY').split("/")
            [wetland_list.append(element) for element in wetland_element]
        return num_of_features, attr_list, wetland_list

    except Exception as e:
        print(e)
        print("Issue with at lat={}, lon={}".format(lat, lon))
        return np.nan
    

nwi_bbox_features()
# Out:
# number of features = 38
# (38,
#  ['L1UBH',
#   'L1UBH',
#   'R4SBC',
#   'R5UBH',
#   'R5UBH',
#   'R5UBH',
#   'R5UBH',
#   'R5UBH',
#   'PUBH',
#   'PUBH',
#   'PUBH',
#   'PUBFx',
#   'PEM1E',
#   'PEM1E',
#   'PEM1E',
#   'PEM1E',
#   'PEM1E',
#   'PEM1E',
#   'PEM1E',
#   'PEM1E',
#   'PEM1E',
#   'PEM1F',
#   'PEM1F',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PFO4E',
#   'PSS1E',
#   'PSS4E',
#   'PSS3',
#   '1E',
#   'PSS1',
#   'EM1E',
#   'PSS3',
#   'EM1E'],
#  ['Lake',
#   'Lake',
#   'Riverine',
#   'Riverine',
#   'Riverine',
#   'Riverine',
#   'Riverine',
#   'Riverine',
#   'Freshwater Pond',
#   'Freshwater Pond',
#   'Freshwater Pond',
#   'Freshwater Pond',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Emergent Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland',
#   'Freshwater Forested',
#   'Shrub Wetland'])

# %%
# read in csv file with SSURGO variables
df_m = pd.read_csv("combined_regular_clean_with_ssurgo_variables.csv")

# %%
def extract_nwi_bbox_variables(df_m_, i, size):

  df_m_["nwi_bbox_vars_" + str(2 * PATCH_SIZE) + "m"] = (df_m_.apply(lambda x: 
                                                     nwi_bbox_features(lat=x.latitude, 
                                                                       lon=x.longitude, 
                                                                       size=size), axis=1))


#   pickle.dump(df_m_, open("NWI_extracted_vars_200mX200m/200mX200m_nwi_variables_part" + str(i),"wb"), protocol=3)        
  (pickle.dump(df_m_, open("NWI_extracted_vars_" + str(2 * PATCH_SIZE) + "m/nwi_extraction_" 
                           + str(2 * PATCH_SIZE) + "X" + str(2 * PATCH_SIZE) + "m"
                           + "_part" + str(i),"wb"), 
               protocol=3))

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2021-03-16 13:37:00.557674

# %%
# pass in batches of 500
# MADHUKAR: 0 - 5000 
# SHOBHA: 5000 - 10000
# RADHIKA: 10000 - 15000

batch_size = 500
MY_NAME = "MADHUKAR"
START = 0 + 5000 * (MY_NAME == "SHOBHA") + 10000 * (MY_NAME == "RADHIKA")

for batch in range(10):
  print("batch {} of 10 started".format(batch + 1))
  batch_df = df_m[START + batch_size * batch : START + batch_size * (batch + 1)].copy()
  extract_nwi_bbox_variables(batch_df, (START + batch_size * batch) + 1, size = PATCH_SIZE)
  print("batch {} of 10 done".format(batch + 1))
# Out:
# batch 1 of 10 started
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 9
# number of features = 0
# number of features = 63
# number of features = 0
# number of features = 20
# number of features = 84
# number of features = 18
# number of features = 17
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 120
# number of features = 19
# number of features = 50
# number of features = 38
# number of features = 0
# number of features = 41
# number of features = 0
# number of features = 0
# number of features = 50
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 46
# number of features = 60
# number of features = 17
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 89
# number of features = 0
# number of features = 59
# number of features = 37
# number of features = 0
# number of features = 41
# number of features = 81
# number of features = 67
# number of features = 26
# number of features = 0
# number of features = 30
# number of features = 0
# number of features = 46
# number of features = 48
# number of features = 48
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 9
# number of features = 48
# number of features = 0
# number of features = 26
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 64
# number of features = 0
# number of features = 14
# number of features = 12
# number of features = 0
# number of features = 23
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 15
# number of features = 0
# number of features = 38
# number of features = 0
# number of features = 10
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 44
# number of features = 0
# number of features = 144
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 26
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 128
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 6
# number of features = 38
# number of features = 15
# number of features = 53
# number of features = 0
# number of features = 59
# number of features = 0
# number of features = 30
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 25
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 42
# number of features = 12
# number of features = 19
# number of features = 32
# number of features = 38
# number of features = 50
# number of features = 8
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 34
# number of features = 0
# number of features = 50
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 77
# number of features = 24
# number of features = 30
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 43
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 51
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 226
# number of features = 32
# number of features = 0
# number of features = 40
# number of features = 99
# number of features = 4
# number of features = 22
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 40
# number of features = 22
# number of features = 0
# number of features = 36
# number of features = 0
# number of features = 0
# number of features = 26
# number of features = 0
# number of features = 6
# number of features = 0
# number of features = 0
# number of features = 28
# number of features = 22
# number of features = 9
# number of features = 0
# number of features = 0
# number of features = 87
# number of features = 0
# number of features = 38
# number of features = 18
# number of features = 40
# number of features = 0
# number of features = 27
# number of features = 28
# number of features = 27
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 14
# number of features = 22
# number of features = 6
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 14
# number of features = 22
# number of features = 0
# number of features = 0
# number of features = 62
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 31
# number of features = 15
# number of features = 23
# number of features = 6
# number of features = 0
# number of features = 22
# number of features = 0
# number of features = 0
# number of features = 14
# number of features = 0
# number of features = 0
# number of features = 72
# number of features = 12
# number of features = 22
# number of features = 0
# number of features = 0
# number of features = 46
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 11
# number of features = 51
# number of features = 0
# number of features = 55
# number of features = 0
# number of features = 41
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 31
# number of features = 0
# number of features = 21
# number of features = 33
# number of features = 0
# number of features = 0
# number of features = 28
# number of features = 0
# number of features = 28
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 28
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 26
# number of features = 0
# number of features = 17
# number of features = 76
# number of features = 27
# number of features = 0
# number of features = 0
# number of features = 14
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 45
# number of features = 0
# number of features = 88
# number of features = 0
# number of features = 38
# number of features = 35
# number of features = 63
# number of features = 29
# number of features = 102
# number of features = 6
# number of features = 31
# number of features = 26
# number of features = 41
# number of features = 47
# number of features = 22
# number of features = 38
# number of features = 21
# number of features = 52
# number of features = 20
# number of features = 35
# number of features = 55
# number of features = 41
# number of features = 73
# number of features = 12
# number of features = 31
# number of features = 49
# number of features = 14
# number of features = 84
# number of features = 40
# number of features = 36
# number of features = 61
# number of features = 27
# number of features = 25
# number of features = 3
# number of features = 1
# number of features = 52
# number of features = 46
# number of features = 31
# number of features = 20
# number of features = 54
# number of features = 11
# number of features = 46
# number of features = 12
# number of features = 25
# number of features = 48
# number of features = 49
# number of features = 51
# number of features = 17
# number of features = 41
# number of features = 34
# number of features = 10
# number of features = 53
# number of features = 76
# number of features = 32
# number of features = 36
# number of features = 42
# number of features = 22
# number of features = 25
# number of features = 22
# number of features = 66
# number of features = 12
# number of features = 23
# number of features = 48
# number of features = 17
# number of features = 64
# number of features = 60
# number of features = 69
# number of features = 52
# number of features = 1
# number of features = 48
# number of features = 36
# number of features = 21
# number of features = 10
# number of features = 8
# number of features = 49
# number of features = 226
# number of features = 38
# number of features = 73
# number of features = 66
# number of features = 16
# number of features = 41
# number of features = 8
# number of features = 38
# number of features = 26
# number of features = 72
# number of features = 12
# number of features = 53
# number of features = 6
# number of features = 0
# number of features = 39
# number of features = 56
# number of features = 76
# number of features = 60
# number of features = 48
# number of features = 60
# number of features = 89
# number of features = 57
# number of features = 74
# number of features = 78
# number of features = 16
# number of features = 51
# number of features = 106
# number of features = 14
# number of features = 41
# number of features = 31
# number of features = 39
# number of features = 28
# number of features = 40
# number of features = 35
# number of features = 50
# number of features = 42
# number of features = 87
# number of features = 38
# number of features = 22
# number of features = 18
# number of features = 36
# number of features = 53
# number of features = 49
# number of features = 70
# number of features = 70
# number of features = 15
# number of features = 47
# number of features = 29
# number of features = 12
# number of features = 15
# number of features = 103
# number of features = 59
# number of features = 15
# number of features = 42
# number of features = 11
# number of features = 94
# number of features = 49
# number of features = 8
# number of features = 25
# number of features = 46
# number of features = 10
# number of features = 32
# number of features = 23
# number of features = 53
# number of features = 52
# number of features = 67
# number of features = 23
# number of features = 48
# number of features = 41
# number of features = 57
# number of features = 18
# number of features = 50
# number of features = 1
# number of features = 47
# number of features = 19
# number of features = 43
# number of features = 28
# number of features = 16
# number of features = 38
# number of features = 51
# number of features = 33
# number of features = 116
# number of features = 88
# number of features = 5
# number of features = 67
# number of features = 9
# number of features = 22
# number of features = 3
# number of features = 13
# number of features = 58
# number of features = 60
# number of features = 32
# number of features = 11
# number of features = 31
# number of features = 62
# number of features = 65
# number of features = 62
# number of features = 28
# number of features = 16
# number of features = 62
# number of features = 34
# number of features = 53
# number of features = 31
# number of features = 34
# number of features = 13
# number of features = 13
# number of features = 59
# number of features = 51
# number of features = 89
# number of features = 36
# number of features = 10
# number of features = 57
# number of features = 39
# number of features = 23
# number of features = 30
# number of features = 19
# number of features = 59
# number of features = 26
# number of features = 32
# number of features = 31
# number of features = 64
# number of features = 23
# number of features = 30
# number of features = 120
# number of features = 50
# number of features = 37
# number of features = 80
# number of features = 78
# number of features = 44
# number of features = 41
# number of features = 23
# number of features = 46
# number of features = 32
# number of features = 134
# number of features = 24
# number of features = 22
# number of features = 23
# number of features = 77
# number of features = 29
# number of features = 62
# number of features = 49
# number of features = 34
# batch 1 of 10 done
# batch 2 of 10 started
# number of features = 69
# number of features = 73
# number of features = 19
# number of features = 20
# number of features = 44
# number of features = 17
# number of features = 3
# number of features = 45
# number of features = 42
# number of features = 42
# number of features = 46
# number of features = 57
# number of features = 24
# number of features = 52
# number of features = 78
# number of features = 22
# number of features = 51
# number of features = 35
# number of features = 25
# number of features = 7
# number of features = 46
# number of features = 26
# number of features = 123
# number of features = 64
# number of features = 17
# number of features = 29
# number of features = 13
# number of features = 31
# number of features = 61
# number of features = 10
# number of features = 130
# number of features = 23
# number of features = 62
# number of features = 17
# number of features = 30
# number of features = 15
# number of features = 67
# number of features = 27
# number of features = 76
# number of features = 14
# number of features = 41
# number of features = 31
# number of features = 60
# number of features = 65
# number of features = 30
# number of features = 38
# number of features = 30
# number of features = 43
# number of features = 13
# number of features = 35
# number of features = 9
# number of features = 57
# number of features = 32
# number of features = 41
# number of features = 25
# number of features = 59
# number of features = 34
# number of features = 16
# number of features = 50
# number of features = 23
# number of features = 30
# number of features = 34
# number of features = 55
# number of features = 31
# number of features = 58
# number of features = 52
# number of features = 31
# number of features = 39
# number of features = 27
# number of features = 18
# number of features = 26
# number of features = 11
# number of features = 30
# number of features = 40
# number of features = 136
# number of features = 25
# number of features = 68
# number of features = 76
# number of features = 46
# number of features = 59
# number of features = 6
# number of features = 65
# number of features = 29
# number of features = 14
# number of features = 30
# number of features = 20
# number of features = 50
# number of features = 12
# number of features = 25
# number of features = 5
# number of features = 66
# number of features = 50
# number of features = 61
# number of features = 25
# number of features = 21
# number of features = 24
# number of features = 17
# number of features = 23
# number of features = 33
# number of features = 35
# number of features = 40
# number of features = 4
# number of features = 28
# number of features = 37
# number of features = 24
# number of features = 46
# number of features = 51
# number of features = 13
# number of features = 44
# number of features = 14
# number of features = 68
# number of features = 11
# number of features = 1
# number of features = 9
# number of features = 19
# number of features = 38
# number of features = 33
# number of features = 90
# number of features = 40
# number of features = 20
# number of features = 25
# number of features = 103
# number of features = 49
# number of features = 5
# number of features = 33
# number of features = 35
# number of features = 42
# number of features = 48
# number of features = 16
# number of features = 46
# number of features = 32
# number of features = 37
# number of features = 18
# number of features = 25
# number of features = 60
# number of features = 11
# number of features = 52
# number of features = 21
# number of features = 34
# number of features = 55
# number of features = 41
# number of features = 62
# number of features = 25
# number of features = 22
# number of features = 57
# number of features = 65
# number of features = 30
# number of features = 50
# number of features = 23
# number of features = 49
# number of features = 42
# number of features = 17
# number of features = 17
# number of features = 29
# number of features = 23
# number of features = 24
# number of features = 55
# number of features = 39
# number of features = 44
# number of features = 29
# number of features = 35
# number of features = 34
# number of features = 25
# number of features = 152
# number of features = 50
# number of features = 41
# number of features = 12
# number of features = 21
# number of features = 38
# number of features = 32
# number of features = 7
# number of features = 77
# number of features = 17
# number of features = 18
# number of features = 21
# number of features = 54
# number of features = 36
# number of features = 63
# number of features = 35
# number of features = 55
# number of features = 68
# number of features = 49
# number of features = 7
# number of features = 49
# number of features = 9
# number of features = 5
# number of features = 52
# number of features = 15
# number of features = 16
# number of features = 36
# number of features = 48
# number of features = 70
# number of features = 46
# number of features = 60
# number of features = 32
# number of features = 10
# number of features = 27
# number of features = 6
# number of features = 47
# number of features = 50
# number of features = 82
# number of features = 38
# number of features = 24
# number of features = 126
# number of features = 46
# number of features = 35
# number of features = 43
# number of features = 13
# number of features = 63
# number of features = 7
# number of features = 15
# number of features = 39
# number of features = 48
# number of features = 4
# number of features = 73
# number of features = 43
# number of features = 22
# number of features = 44
# number of features = 8
# number of features = 27
# number of features = 48
# number of features = 52
# number of features = 57
# number of features = 48
# number of features = 34
# number of features = 53
# number of features = 24
# number of features = 27
# number of features = 16
# number of features = 49
# number of features = 52
# number of features = 17
# number of features = 42
# number of features = 68
# number of features = 16
# number of features = 37
# number of features = 22
# number of features = 17
# number of features = 24
# number of features = 61
# number of features = 12
# number of features = 34
# number of features = 12
# number of features = 43
# number of features = 25
# number of features = 15
# number of features = 49
# number of features = 8
# number of features = 44
# number of features = 54
# number of features = 17
# number of features = 26
# number of features = 37
# number of features = 32
# number of features = 18
# number of features = 62
# number of features = 82
# number of features = 44
# number of features = 41
# number of features = 36
# number of features = 45
# number of features = 88
# number of features = 7
# number of features = 66
# number of features = 26
# number of features = 65
# number of features = 27
# number of features = 48
# number of features = 24
# number of features = 59
# number of features = 46
# number of features = 16
# number of features = 51
# number of features = 49
# number of features = 38
# number of features = 60
# number of features = 47
# number of features = 14
# number of features = 82
# number of features = 38
# number of features = 36
# number of features = 19
# number of features = 31
# number of features = 7
# number of features = 30
# number of features = 44
# number of features = 25
# number of features = 20
# number of features = 27
# number of features = 50
# number of features = 44
# number of features = 25
# number of features = 26
# number of features = 38
# number of features = 18
# number of features = 28
# number of features = 25
# number of features = 23
# number of features = 14
# number of features = 18
# number of features = 39
# number of features = 36
# number of features = 57
# number of features = 23
# number of features = 210
# number of features = 14
# number of features = 16
# number of features = 46
# number of features = 43
# number of features = 24
# number of features = 102
# number of features = 46
# number of features = 42
# number of features = 30
# number of features = 21
# number of features = 18
# number of features = 24
# number of features = 0
# number of features = 35
# number of features = 26
# number of features = 68
# number of features = 65
# number of features = 20
# number of features = 39
# number of features = 73
# number of features = 59
# number of features = 50
# number of features = 48
# number of features = 31
# number of features = 59
# number of features = 53
# number of features = 64
# number of features = 35
# number of features = 100
# number of features = 27
# number of features = 65
# number of features = 11
# number of features = 34
# number of features = 56
# number of features = 43
# number of features = 83
# number of features = 41
# number of features = 20
# number of features = 15
# number of features = 25
# number of features = 22
# number of features = 35
# number of features = 60
# number of features = 31
# number of features = 16
# number of features = 74
# number of features = 38
# number of features = 38
# number of features = 48
# number of features = 50
# number of features = 71
# number of features = 33
# number of features = 47
# number of features = 37
# number of features = 10
# number of features = 68
# number of features = 46
# number of features = 55
# number of features = 130
# number of features = 33
# number of features = 174
# number of features = 76
# number of features = 66
# number of features = 38
# number of features = 41
# number of features = 83
# number of features = 25
# number of features = 61
# number of features = 17
# number of features = 140
# number of features = 61
# number of features = 35
# number of features = 77
# number of features = 16
# number of features = 122
# number of features = 47
# number of features = 91
# number of features = 50
# number of features = 54
# number of features = 80
# number of features = 55
# number of features = 49
# number of features = 71
# number of features = 75
# number of features = 25
# number of features = 33
# number of features = 174
# number of features = 225
# number of features = 18
# number of features = 94
# number of features = 59
# number of features = 22
# number of features = 61
# number of features = 154
# number of features = 55
# number of features = 56
# number of features = 26
# number of features = 50
# number of features = 243
# number of features = 67
# number of features = 7
# number of features = 24
# number of features = 53
# number of features = 90
# number of features = 262
# number of features = 19
# number of features = 8
# number of features = 23
# number of features = 40
# number of features = 46
# number of features = 55
# number of features = 31
# number of features = 158
# number of features = 67
# number of features = 31
# number of features = 75
# number of features = 52
# number of features = 26
# number of features = 12
# number of features = 53
# number of features = 10
# number of features = 52
# number of features = 62
# number of features = 20
# number of features = 70
# number of features = 58
# number of features = 15
# number of features = 61
# number of features = 68
# number of features = 81
# number of features = 32
# number of features = 46
# number of features = 92
# number of features = 79
# number of features = 24
# number of features = 18
# number of features = 59
# number of features = 19
# number of features = 53
# number of features = 47
# number of features = 42
# number of features = 25
# number of features = 79
# number of features = 68
# number of features = 36
# number of features = 52
# number of features = 38
# number of features = 186
# number of features = 50
# number of features = 38
# number of features = 59
# number of features = 57
# number of features = 83
# number of features = 26
# number of features = 24
# number of features = 89
# number of features = 76
# number of features = 51
# number of features = 128
# number of features = 99
# number of features = 17
# number of features = 9
# number of features = 68
# number of features = 17
# number of features = 66
# number of features = 87
# number of features = 173
# number of features = 48
# number of features = 26
# number of features = 34
# number of features = 46
# number of features = 32
# number of features = 80
# number of features = 9
# number of features = 18
# number of features = 106
# number of features = 82
# number of features = 11
# number of features = 49
# number of features = 74
# number of features = 49
# number of features = 38
# number of features = 84
# number of features = 34
# number of features = 44
# number of features = 178
# number of features = 103
# number of features = 71
# number of features = 77
# number of features = 59
# number of features = 63
# number of features = 27
# number of features = 92
# number of features = 132
# number of features = 15
# batch 2 of 10 done
# batch 3 of 10 started
# number of features = 142
# number of features = 110
# number of features = 10
# number of features = 57
# number of features = 34
# number of features = 87
# number of features = 47
# number of features = 152
# number of features = 82
# number of features = 30
# number of features = 40
# number of features = 29
# number of features = 89
# number of features = 65
# number of features = 53
# number of features = 7
# number of features = 26
# number of features = 60
# number of features = 79
# number of features = 72
# number of features = 62
# number of features = 78
# number of features = 37
# number of features = 158
# number of features = 33
# number of features = 31
# number of features = 29
# number of features = 41
# number of features = 24
# number of features = 23
# number of features = 60
# number of features = 18
# number of features = 8
# number of features = 9
# number of features = 82
# number of features = 13
# number of features = 23
# number of features = 21
# number of features = 25
# number of features = 8
# number of features = 19
# number of features = 26
# number of features = 59
# number of features = 16
# number of features = 20
# number of features = 12
# number of features = 25
# number of features = 52
# number of features = 49
# number of features = 41
# number of features = 8
# number of features = 20
# number of features = 34
# number of features = 12
# number of features = 24
# number of features = 42
# number of features = 25
# number of features = 42
# number of features = 88
# number of features = 63
# number of features = 18
# number of features = 34
# number of features = 14
# number of features = 20
# number of features = 23
# number of features = 46
# number of features = 31
# number of features = 51
# number of features = 28
# number of features = 20
# number of features = 17
# number of features = 12
# number of features = 44
# number of features = 45
# number of features = 38
# number of features = 39
# number of features = 24
# number of features = 48
# number of features = 32
# number of features = 5
# number of features = 24
# number of features = 16
# number of features = 34
# number of features = 43
# number of features = 8
# number of features = 42
# number of features = 14
# number of features = 9
# number of features = 46
# number of features = 27
# number of features = 10
# number of features = 86
# number of features = 6
# number of features = 11
# number of features = 20
# number of features = 45
# number of features = 65
# number of features = 50
# number of features = 34
# number of features = 54
# number of features = 38
# number of features = 48
# number of features = 59
# number of features = 54
# number of features = 37
# number of features = 15
# number of features = 35
# number of features = 17
# number of features = 24
# number of features = 80
# number of features = 11
# number of features = 45
# number of features = 9
# number of features = 9
# number of features = 16
# number of features = 36
# number of features = 75
# number of features = 28
# number of features = 29
# number of features = 12
# number of features = 62
# number of features = 47
# number of features = 2
# number of features = 18
# number of features = 14
# number of features = 26
# number of features = 38
# number of features = 58
# number of features = 48
# number of features = 42
# number of features = 16
# number of features = 9
# number of features = 51
# number of features = 50
# number of features = 55
# number of features = 36
# number of features = 39
# number of features = 25
# number of features = 38
# number of features = 32
# number of features = 89
# number of features = 30
# number of features = 7
# number of features = 64
# number of features = 13
# number of features = 39
# number of features = 12
# number of features = 14
# number of features = 23
# number of features = 49
# number of features = 16
# number of features = 38
# number of features = 7
# number of features = 10
# number of features = 13
# number of features = 46
# number of features = 30
# number of features = 52
# number of features = 44
# number of features = 11
# number of features = 29
# number of features = 73
# number of features = 15
# number of features = 60
# number of features = 60
# number of features = 29
# number of features = 39
# number of features = 55
# number of features = 25
# number of features = 35
# number of features = 62
# number of features = 30
# number of features = 34
# number of features = 26
# number of features = 26
# number of features = 45
# number of features = 54
# number of features = 36
# number of features = 38
# number of features = 7
# number of features = 39
# number of features = 24
# number of features = 26
# number of features = 42
# number of features = 68
# number of features = 49
# number of features = 20
# number of features = 57
# number of features = 47
# number of features = 15
# number of features = 42
# number of features = 26
# number of features = 26
# number of features = 51
# number of features = 13
# number of features = 8
# number of features = 62
# number of features = 53
# number of features = 40
# number of features = 64
# number of features = 47
# number of features = 72
# number of features = 45
# number of features = 26
# number of features = 31
# number of features = 55
# number of features = 21
# number of features = 30
# number of features = 21
# number of features = 29
# number of features = 69
# number of features = 31
# number of features = 28
# number of features = 30
# number of features = 27
# number of features = 55
# number of features = 46
# number of features = 61
# number of features = 53
# number of features = 26
# number of features = 56
# number of features = 23
# number of features = 21
# number of features = 15
# number of features = 20
# number of features = 16
# number of features = 47
# number of features = 34
# number of features = 8
# number of features = 10
# number of features = 36
# number of features = 15
# number of features = 41
# number of features = 51
# number of features = 16
# number of features = 28
# number of features = 83
# number of features = 50
# number of features = 29
# number of features = 24
# number of features = 37
# number of features = 23
# number of features = 32
# number of features = 20
# number of features = 18
# number of features = 55
# number of features = 27
# number of features = 41
# number of features = 60
# number of features = 47
# number of features = 28
# number of features = 42
# number of features = 26
# number of features = 42
# number of features = 6
# number of features = 38
# number of features = 41
# number of features = 58
# number of features = 37
# number of features = 54
# number of features = 12
# number of features = 64
# number of features = 40
# number of features = 44
# number of features = 33
# number of features = 13
# number of features = 50
# number of features = 38
# number of features = 15
# number of features = 34
# number of features = 12
# number of features = 4
# number of features = 13
# number of features = 22
# number of features = 21
# number of features = 56
# number of features = 35
# number of features = 29
# number of features = 13
# number of features = 41
# number of features = 40
# number of features = 32
# number of features = 38
# number of features = 50
# number of features = 8
# number of features = 41
# number of features = 11
# number of features = 20
# number of features = 16
# number of features = 44
# number of features = 6
# number of features = 30
# number of features = 28
# number of features = 8
# number of features = 21
# number of features = 52
# number of features = 17
# number of features = 10
# number of features = 12
# number of features = 34
# number of features = 27
# number of features = 32
# number of features = 38
# number of features = 36
# number of features = 36
# number of features = 35
# number of features = 44
# number of features = 24
# number of features = 13
# number of features = 43
# number of features = 67
# number of features = 33
# number of features = 45
# number of features = 17
# number of features = 25
# number of features = 52
# number of features = 36
# number of features = 43
# number of features = 44
# number of features = 48
# number of features = 42
# number of features = 24
# number of features = 53
# number of features = 21
# number of features = 39
# number of features = 16
# number of features = 62
# number of features = 11
# number of features = 44
# number of features = 25
# number of features = 15
# number of features = 1
# number of features = 13
# number of features = 32
# number of features = 28
# number of features = 38
# number of features = 49
# number of features = 18
# number of features = 14
# number of features = 27
# number of features = 64
# number of features = 51
# number of features = 42
# number of features = 37
# number of features = 54
# number of features = 16
# number of features = 51
# number of features = 10
# number of features = 69
# number of features = 36
# number of features = 54
# number of features = 18
# number of features = 12
# number of features = 60
# number of features = 46
# number of features = 14
# number of features = 19
# number of features = 122
# number of features = 26
# number of features = 68
# number of features = 54
# number of features = 22
# number of features = 7
# number of features = 22
# number of features = 33
# number of features = 48
# number of features = 90
# number of features = 25
# number of features = 16
# number of features = 31
# number of features = 23
# number of features = 60
# number of features = 14
# number of features = 39
# number of features = 14
# number of features = 38
# number of features = 37
# number of features = 29
# number of features = 60
# number of features = 43
# number of features = 43
# number of features = 17
# number of features = 14
# number of features = 24
# number of features = 16
# number of features = 51
# number of features = 132
# number of features = 10
# number of features = 80
# number of features = 32
# number of features = 21
# number of features = 19
# number of features = 25
# number of features = 6
# number of features = 33
# number of features = 26
# number of features = 18
# number of features = 36
# number of features = 34
# number of features = 35
# number of features = 25
# number of features = 28
# number of features = 68
# number of features = 13
# number of features = 19
# number of features = 38
# number of features = 30
# number of features = 13
# number of features = 12
# number of features = 60
# number of features = 19
# number of features = 18
# number of features = 50
# number of features = 9
# number of features = 37
# number of features = 32
# number of features = 57
# number of features = 12
# number of features = 41
# number of features = 40
# number of features = 85
# number of features = 25
# number of features = 34
# number of features = 42
# number of features = 41
# number of features = 26
# number of features = 35
# number of features = 26
# number of features = 44
# number of features = 28
# number of features = 50
# number of features = 26
# number of features = 34
# number of features = 33
# number of features = 27
# number of features = 11
# number of features = 15
# number of features = 17
# number of features = 4
# number of features = 21
# number of features = 14
# number of features = 15
# number of features = 27
# number of features = 48
# number of features = 43
# number of features = 12
# number of features = 11
# number of features = 21
# number of features = 52
# number of features = 26
# number of features = 10
# number of features = 22
# number of features = 45
# number of features = 27
# number of features = 36
# number of features = 20
# number of features = 42
# number of features = 30
# number of features = 26
# number of features = 31
# number of features = 72
# number of features = 24
# number of features = 33
# number of features = 13
# number of features = 114
# number of features = 18
# number of features = 26
# number of features = 20
# number of features = 22
# number of features = 48
# number of features = 55
# number of features = 32
# number of features = 28
# number of features = 37
# number of features = 22
# number of features = 38
# number of features = 37
# number of features = 17
# number of features = 51
# number of features = 34
# number of features = 23
# number of features = 22
# number of features = 37
# number of features = 29
# number of features = 21
# number of features = 2
# number of features = 81
# number of features = 55
# number of features = 32
# number of features = 55
# number of features = 4
# number of features = 111
# number of features = 23
# number of features = 27
# number of features = 12
# number of features = 85
# number of features = 29
# number of features = 15
# number of features = 27
# number of features = 20
# batch 3 of 10 done
# batch 4 of 10 started
# number of features = 15
# number of features = 12
# number of features = 36
# number of features = 9
# number of features = 49
# number of features = 48
# number of features = 35
# number of features = 58
# number of features = 2
# number of features = 72
# number of features = 23
# number of features = 8
# number of features = 12
# number of features = 26
# number of features = 37
# number of features = 35
# number of features = 12
# number of features = 50
# number of features = 11
# number of features = 9
# number of features = 22
# number of features = 34
# number of features = 6
# number of features = 35
# number of features = 58
# number of features = 29
# number of features = 19
# number of features = 49
# number of features = 49
# number of features = 33
# number of features = 28
# number of features = 111
# number of features = 23
# number of features = 17
# number of features = 32
# number of features = 14
# number of features = 42
# number of features = 31
# number of features = 1
# number of features = 12
# number of features = 25
# number of features = 46
# number of features = 29
# number of features = 64
# number of features = 13
# number of features = 30
# number of features = 62
# number of features = 27
# number of features = 48
# number of features = 31
# number of features = 12
# number of features = 29
# number of features = 31
# number of features = 24
# number of features = 49
# number of features = 60
# number of features = 27
# number of features = 34
# number of features = 53
# number of features = 39
# number of features = 64
# number of features = 31
# number of features = 44
# number of features = 56
# number of features = 22
# number of features = 44
# number of features = 35
# number of features = 55
# number of features = 51
# number of features = 22
# number of features = 28
# number of features = 62
# number of features = 54
# number of features = 28
# number of features = 16
# number of features = 88
# number of features = 36
# number of features = 35
# number of features = 4
# number of features = 5
# number of features = 110
# number of features = 39
# number of features = 28
# number of features = 64
# number of features = 12
# number of features = 69
# number of features = 19
# number of features = 35
# number of features = 37
# number of features = 27
# number of features = 35
# number of features = 4
# number of features = 51
# number of features = 86
# number of features = 9
# number of features = 51
# number of features = 16
# number of features = 48
# number of features = 26
# number of features = 35
# number of features = 52
# number of features = 54
# number of features = 15
# number of features = 33
# number of features = 19
# number of features = 20
# number of features = 47
# number of features = 31
# number of features = 40
# number of features = 17
# number of features = 44
# number of features = 60
# number of features = 19
# number of features = 14
# number of features = 15
# number of features = 39
# number of features = 45
# number of features = 20
# number of features = 44
# number of features = 49
# number of features = 8
# number of features = 18
# number of features = 56
# number of features = 11
# number of features = 47
# number of features = 13
# number of features = 8
# number of features = 52
# number of features = 24
# number of features = 117
# number of features = 48
# number of features = 29
# number of features = 35
# number of features = 49
# number of features = 24
# number of features = 10
# number of features = 20
# number of features = 28
# number of features = 18
# number of features = 36
# number of features = 31
# number of features = 37
# number of features = 16
# number of features = 146
# number of features = 42
# number of features = 16
# number of features = 35
# number of features = 41
# number of features = 36
# number of features = 10
# number of features = 68
# number of features = 46
# number of features = 33
# number of features = 35
# number of features = 80
# number of features = 68
# number of features = 44
# number of features = 20
# number of features = 28
# number of features = 25
# number of features = 8
# number of features = 39
# number of features = 41
# number of features = 30
# number of features = 48
# number of features = 52
# number of features = 21
# number of features = 146
# number of features = 23
# number of features = 54
# number of features = 61
# number of features = 12
# number of features = 33
# number of features = 23
# number of features = 47
# number of features = 41
# number of features = 16
# number of features = 22
# number of features = 26
# number of features = 47
# number of features = 52
# number of features = 24
# number of features = 15
# number of features = 70
# number of features = 106
# number of features = 11
# number of features = 55
# number of features = 22
# number of features = 42
# number of features = 20
# number of features = 26
# number of features = 32
# number of features = 12
# number of features = 26
# number of features = 56
# number of features = 12
# number of features = 22
# number of features = 29
# number of features = 106
# number of features = 130
# number of features = 14
# number of features = 54
# number of features = 25
# number of features = 31
# number of features = 42
# number of features = 39
# number of features = 23
# number of features = 13
# number of features = 20
# number of features = 42
# number of features = 17
# number of features = 40
# number of features = 31
# number of features = 30
# number of features = 22
# number of features = 20
# number of features = 51
# number of features = 24
# number of features = 2
# number of features = 23
# number of features = 112
# number of features = 16
# number of features = 23
# number of features = 20
# number of features = 28
# number of features = 9
# number of features = 7
# number of features = 50
# number of features = 61
# number of features = 29
# number of features = 34
# number of features = 17
# number of features = 20
# number of features = 19
# number of features = 30
# number of features = 13
# number of features = 97
# number of features = 22
# number of features = 40
# number of features = 27
# number of features = 14
# number of features = 21
# number of features = 1
# number of features = 135
# number of features = 78
# number of features = 35
# number of features = 64
# number of features = 30
# number of features = 19
# number of features = 30
# number of features = 49
# number of features = 20
# number of features = 34
# number of features = 52
# number of features = 17
# number of features = 22
# number of features = 38
# number of features = 6
# number of features = 49
# number of features = 31
# number of features = 74
# number of features = 18
# number of features = 32
# number of features = 62
# number of features = 18
# number of features = 56
# number of features = 58
# number of features = 18
# number of features = 38
# number of features = 50
# number of features = 7
# number of features = 10
# number of features = 142
# number of features = 22
# number of features = 15
# number of features = 18
# number of features = 41
# number of features = 30
# number of features = 13
# number of features = 33
# number of features = 23
# number of features = 12
# number of features = 18
# number of features = 8
# number of features = 13
# number of features = 48
# number of features = 39
# number of features = 13
# number of features = 35
# number of features = 49
# number of features = 16
# number of features = 29
# number of features = 10
# number of features = 16
# number of features = 12
# number of features = 21
# number of features = 12
# number of features = 10
# number of features = 28
# number of features = 41
# number of features = 13
# number of features = 77
# number of features = 31
# number of features = 17
# number of features = 41
# number of features = 20
# number of features = 37
# number of features = 22
# number of features = 21
# number of features = 34
# number of features = 50
# number of features = 26
# number of features = 33
# number of features = 32
# number of features = 44
# number of features = 46
# number of features = 22
# number of features = 29
# number of features = 35
# number of features = 29
# number of features = 34
# number of features = 21
# number of features = 36
# number of features = 27
# number of features = 23
# number of features = 20
# number of features = 22
# number of features = 25
# number of features = 18
# number of features = 21
# number of features = 41
# number of features = 38
# number of features = 32
# number of features = 40
# number of features = 21
# number of features = 19
# number of features = 48
# number of features = 18
# number of features = 59
# number of features = 22
# number of features = 17
# number of features = 40
# number of features = 34
# number of features = 30
# number of features = 33
# number of features = 21
# number of features = 41
# number of features = 17
# number of features = 40
# number of features = 28
# number of features = 36
# number of features = 18
# number of features = 35
# number of features = 17
# number of features = 46
# number of features = 44
# number of features = 40
# number of features = 22
# number of features = 18
# number of features = 36
# number of features = 15
# number of features = 7
# number of features = 20
# number of features = 108
# number of features = 27
# number of features = 11
# number of features = 38
# number of features = 12
# number of features = 42
# number of features = 27
# number of features = 8
# number of features = 35
# number of features = 23
# number of features = 46
# number of features = 44
# number of features = 25
# number of features = 27
# number of features = 17
# number of features = 58
# number of features = 54
# number of features = 27
# number of features = 21
# number of features = 20
# number of features = 17
# number of features = 37
# number of features = 15
# number of features = 22
# number of features = 7
# number of features = 51
# number of features = 22
# number of features = 54
# number of features = 28
# number of features = 31
# number of features = 28
# number of features = 29
# number of features = 41
# number of features = 40
# number of features = 22
# number of features = 16
# number of features = 32
# number of features = 7
# number of features = 34
# number of features = 26
# number of features = 30
# number of features = 15
# number of features = 22
# number of features = 21
# number of features = 25
# number of features = 33
# number of features = 39
# number of features = 68
# number of features = 44
# number of features = 8
# number of features = 18
# number of features = 16
# number of features = 29
# number of features = 12
# number of features = 14
# number of features = 118
# number of features = 74
# number of features = 36
# number of features = 11
# number of features = 27
# number of features = 10
# number of features = 64
# number of features = 11
# number of features = 2
# number of features = 13
# number of features = 15
# number of features = 22
# number of features = 8
# number of features = 25
# number of features = 24
# number of features = 2
# number of features = 42
# number of features = 13
# number of features = 7
# number of features = 87
# number of features = 14
# number of features = 52
# number of features = 27
# number of features = 10
# number of features = 28
# number of features = 32
# number of features = 12
# number of features = 49
# number of features = 16
# number of features = 6
# number of features = 26
# number of features = 10
# number of features = 0
# number of features = 35
# number of features = 0
# number of features = 28
# number of features = 20
# number of features = 0
# number of features = 8
# number of features = 6
# number of features = 62
# number of features = 0
# number of features = 26
# number of features = 16
# number of features = 11
# number of features = 13
# number of features = 0
# number of features = 0
# number of features = 29
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 21
# number of features = 13
# number of features = 11
# number of features = 36
# number of features = 7
# number of features = 26
# number of features = 18
# number of features = 0
# number of features = 0
# number of features = 85
# number of features = 21
# number of features = 42
# number of features = 23
# number of features = 39
# number of features = 16
# number of features = 15
# number of features = 35
# number of features = 21
# number of features = 50
# number of features = 21
# number of features = 0
# number of features = 13
# number of features = 19
# number of features = 0
# number of features = 32
# number of features = 0
# number of features = 37
# number of features = 0
# number of features = 0
# number of features = 54
# batch 4 of 10 done
# batch 5 of 10 started
# number of features = 0
# number of features = 0
# ...
# number of features = 69
# number of features = 87
# number of features = 72
# number of features = 48
# number of features = 27
# number of features = 110
# number of features = 23
# number of features = 136
# number of features = 60
# number of features = 43
# number of features = 55
# number of features = 64
# number of features = 250
# number of features = 44
# number of features = 98
# number of features = 80
# number of features = 46
# number of features = 8
# number of features = 70
# number of features = 53
# number of features = 226
# number of features = 65
# number of features = 102
# number of features = 8
# number of features = 125
# number of features = 81
# number of features = 220
# number of features = 138
# number of features = 25
# number of features = 76
# number of features = 7
# number of features = 56
# number of features = 11
# number of features = 124
# number of features = 64
# number of features = 12
# number of features = 38
# number of features = 183
# number of features = 230
# number of features = 46
# number of features = 192
# number of features = 38
# number of features = 38
# number of features = 105
# number of features = 142
# number of features = 106
# number of features = 36
# number of features = 57
# number of features = 68
# number of features = 45
# number of features = 50
# number of features = 72
# number of features = 54
# number of features = 6
# number of features = 43
# number of features = 132
# number of features = 103
# number of features = 111
# number of features = 90
# number of features = 79
# number of features = 110
# number of features = 136
# number of features = 101
# number of features = 17
# number of features = 5
# number of features = 139
# number of features = 46
# number of features = 180
# number of features = 103
# number of features = 4
# number of features = 109
# number of features = 103
# number of features = 17
# number of features = 98
# number of features = 46
# number of features = 21
# number of features = 26
# number of features = 64
# number of features = 52
# number of features = 119
# number of features = 132
# number of features = 222
# number of features = 36
# number of features = 81
# number of features = 119
# number of features = 46
# number of features = 20
# number of features = 306
# number of features = 45
# number of features = 127
# number of features = 13
# number of features = 76
# number of features = 126
# number of features = 168
# number of features = 111
# number of features = 33
# number of features = 242
# number of features = 69
# number of features = 108
# number of features = 135
# number of features = 1
# number of features = 15
# number of features = 54
# number of features = 146
# number of features = 79
# number of features = 120
# number of features = 61
# number of features = 390
# number of features = 89
# number of features = 74
# number of features = 58
# number of features = 62
# number of features = 80
# number of features = 67
# number of features = 0
# number of features = 162
# number of features = 93
# number of features = 68
# number of features = 93
# number of features = 127
# number of features = 39
# number of features = 122
# number of features = 83
# number of features = 164
# number of features = 53
# number of features = 41
# number of features = 8
# number of features = 248
# number of features = 19
# number of features = 108
# number of features = 156
# number of features = 164
# number of features = 42
# number of features = 50
# number of features = 53
# number of features = 177
# number of features = 73
# number of features = 50
# number of features = 4
# number of features = 24
# number of features = 22
# number of features = 119
# number of features = 11
# number of features = 38
# number of features = 99
# number of features = 61
# number of features = 106
# number of features = 118
# number of features = 197
# number of features = 123
# number of features = 68
# number of features = 50
# number of features = 16
# number of features = 29
# number of features = 12
# batch 9 of 10 done
# batch 10 of 10 started
# number of features = 102
# number of features = 54
# number of features = 36
# number of features = 106
# number of features = 18
# number of features = 32
# number of features = 66
# number of features = 146
# number of features = 222
# number of features = 134
# number of features = 105
# number of features = 12
# number of features = 120
# number of features = 99
# number of features = 122
# number of features = 112
# number of features = 51
# number of features = 68
# number of features = 65
# number of features = 37
# number of features = 58
# number of features = 91
# number of features = 86
# number of features = 11
# number of features = 25
# number of features = 189
# number of features = 197
# number of features = 114
# number of features = 110
# number of features = 72
# number of features = 157
# number of features = 87
# number of features = 8
# number of features = 104
# number of features = 130
# number of features = 200
# number of features = 35
# number of features = 91
# number of features = 89
# number of features = 56
# number of features = 148
# number of features = 55
# number of features = 144
# number of features = 47
# number of features = 102
# number of features = 75
# number of features = 48
# number of features = 31
# number of features = 166
# number of features = 73
# number of features = 83
# number of features = 59
# number of features = 34
# number of features = 42
# number of features = 127
# number of features = 62
# number of features = 163
# number of features = 70
# number of features = 92
# number of features = 42
# number of features = 102
# number of features = 224
# number of features = 65
# number of features = 94
# number of features = 84
# number of features = 112
# number of features = 30
# number of features = 36
# number of features = 65
# number of features = 27
# number of features = 48
# number of features = 48
# number of features = 68
# number of features = 83
# number of features = 67
# number of features = 11
# number of features = 83
# number of features = 328
# number of features = 15
# number of features = 9
# number of features = 134
# number of features = 85
# number of features = 96
# number of features = 175
# number of features = 17
# number of features = 156
# number of features = 152
# number of features = 28
# number of features = 8
# number of features = 10
# number of features = 155
# number of features = 54
# number of features = 131
# number of features = 55
# number of features = 182
# number of features = 140
# number of features = 119
# number of features = 45
# number of features = 83
# number of features = 139
# number of features = 166
# number of features = 72
# number of features = 40
# number of features = 51
# number of features = 19
# number of features = 130
# number of features = 103
# number of features = 67
# number of features = 115
# number of features = 39
# number of features = 33
# number of features = 88
# number of features = 49
# number of features = 31
# number of features = 127
# number of features = 116
# number of features = 76
# number of features = 11
# number of features = 56
# number of features = 147
# number of features = 110
# number of features = 61
# number of features = 67
# number of features = 52
# number of features = 221
# number of features = 26
# number of features = 73
# number of features = 85
# number of features = 15
# number of features = 74
# number of features = 25
# number of features = 54
# number of features = 39
# number of features = 94
# number of features = 8
# number of features = 107
# number of features = 27
# number of features = 82
# number of features = 7
# number of features = 21
# number of features = 47
# number of features = 160
# number of features = 24
# number of features = 21
# number of features = 47
# number of features = 15
# number of features = 53
# number of features = 46
# number of features = 4
# number of features = 113
# number of features = 35
# number of features = 86
# number of features = 88
# number of features = 142
# number of features = 156
# number of features = 64
# number of features = 75
# number of features = 58
# number of features = 77
# number of features = 79
# number of features = 239
# number of features = 146
# number of features = 76
# number of features = 198
# number of features = 58
# number of features = 179
# number of features = 217
# number of features = 70
# number of features = 50
# number of features = 111
# number of features = 50
# number of features = 157
# number of features = 72
# number of features = 56
# number of features = 63
# number of features = 159
# number of features = 38
# number of features = 180
# number of features = 32
# number of features = 78
# number of features = 70
# number of features = 30
# number of features = 65
# number of features = 76
# number of features = 216
# number of features = 121
# number of features = 49
# number of features = 134
# number of features = 88
# number of features = 96
# number of features = 75
# number of features = 20
# number of features = 34
# number of features = 12
# number of features = 104
# number of features = 33
# number of features = 66
# number of features = 118
# number of features = 48
# number of features = 215
# number of features = 115
# number of features = 61
# number of features = 44
# number of features = 163
# number of features = 48
# number of features = 74
# number of features = 154
# number of features = 97
# number of features = 79
# number of features = 72
# number of features = 61
# number of features = 72
# number of features = 47
# number of features = 79
# number of features = 43
# number of features = 106
# number of features = 124
# number of features = 194
# number of features = 45
# number of features = 69
# number of features = 56
# number of features = 162
# number of features = 64
# number of features = 200
# number of features = 25
# number of features = 100
# number of features = 81
# number of features = 54
# number of features = 108
# number of features = 166
# number of features = 99
# number of features = 148
# number of features = 30
# number of features = 15
# number of features = 77
# number of features = 21
# number of features = 146
# number of features = 190
# number of features = 64
# number of features = 88
# number of features = 64
# number of features = 245
# number of features = 120
# number of features = 104
# number of features = 45
# number of features = 68
# number of features = 80
# number of features = 109
# number of features = 42
# number of features = 88
# number of features = 75
# number of features = 17
# number of features = 80
# number of features = 41
# number of features = 98
# number of features = 69
# number of features = 139
# number of features = 115
# number of features = 61
# number of features = 87
# number of features = 21
# number of features = 16
# number of features = 44
# number of features = 117
# number of features = 125
# number of features = 101
# number of features = 109
# number of features = 13
# number of features = 78
# number of features = 24
# number of features = 44
# number of features = 151
# number of features = 70
# number of features = 17
# number of features = 38
# number of features = 16
# number of features = 25
# number of features = 45
# number of features = 47
# number of features = 68
# number of features = 60
# number of features = 126
# number of features = 36
# number of features = 60
# number of features = 206
# number of features = 49
# number of features = 69
# number of features = 65
# number of features = 147
# number of features = 117
# number of features = 39
# number of features = 112
# number of features = 93
# number of features = 21
# number of features = 56
# number of features = 45
# number of features = 178
# number of features = 107
# number of features = 181
# number of features = 100
# number of features = 151
# number of features = 14
# number of features = 51
# number of features = 22
# number of features = 35
# number of features = 23
# number of features = 135
# number of features = 80
# number of features = 51
# number of features = 99
# number of features = 71
# number of features = 89
# number of features = 70
# number of features = 56
# number of features = 45
# number of features = 86
# number of features = 100
# number of features = 56
# number of features = 56
# number of features = 169
# number of features = 58
# number of features = 183
# number of features = 43
# number of features = 18
# number of features = 38
# number of features = 53
# number of features = 24
# number of features = 147
# number of features = 74
# number of features = 112
# number of features = 52
# number of features = 138
# number of features = 46
# number of features = 42
# number of features = 33
# number of features = 95
# number of features = 142
# number of features = 75
# number of features = 39
# number of features = 26
# number of features = 54
# number of features = 57
# number of features = 67
# number of features = 202
# number of features = 124
# number of features = 175
# number of features = 74
# number of features = 51
# number of features = 35
# number of features = 73
# number of features = 67
# number of features = 66
# number of features = 140
# number of features = 26
# number of features = 152
# number of features = 63
# number of features = 68
# number of features = 109
# number of features = 95
# number of features = 36
# number of features = 79
# number of features = 174
# number of features = 162
# number of features = 34
# number of features = 162
# number of features = 160
# number of features = 101
# number of features = 79
# number of features = 53
# number of features = 27
# number of features = 24
# number of features = 38
# number of features = 112
# number of features = 37
# number of features = 21
# number of features = 128
# number of features = 155
# number of features = 164
# number of features = 51
# number of features = 48
# number of features = 48
# number of features = 95
# number of features = 60
# number of features = 29
# number of features = 17
# number of features = 72
# number of features = 58
# number of features = 136
# number of features = 11
# number of features = 121
# number of features = 106
# number of features = 106
# number of features = 109
# number of features = 137
# number of features = 44
# number of features = 100
# number of features = 50
# number of features = 121
# number of features = 27
# number of features = 200
# number of features = 183
# number of features = 27
# number of features = 47
# number of features = 96
# number of features = 23
# number of features = 26
# number of features = 169
# number of features = 238
# number of features = 193
# number of features = 2
# number of features = 27
# number of features = 73
# number of features = 138
# number of features = 289
# number of features = 124
# number of features = 62
# number of features = 43
# number of features = 193
# number of features = 81
# number of features = 129
# number of features = 74
# number of features = 112
# number of features = 452
# number of features = 108
# number of features = 120
# number of features = 76
# number of features = 120
# number of features = 137
# number of features = 16
# number of features = 276
# number of features = 101
# number of features = 274
# number of features = 190
# number of features = 180
# number of features = 32
# number of features = 139
# number of features = 280
# number of features = 58
# number of features = 21
# number of features = 104
# number of features = 61
# number of features = 82
# number of features = 106
# number of features = 75
# number of features = 63
# number of features = 47
# number of features = 29
# number of features = 10
# number of features = 383
# number of features = 38
# number of features = 96
# number of features = 63
# number of features = 90
# number of features = 78
# number of features = 85
# number of features = 39
# number of features = 138
# number of features = 195
# number of features = 93
# number of features = 145
# number of features = 76
# number of features = 83
# number of features = 71
# number of features = 60
# number of features = 141
# number of features = 105
# number of features = 236
# number of features = 129
# number of features = 95
# number of features = 74
# number of features = 64
# number of features = 114
# number of features = 118
# number of features = 133
# number of features = 21
# number of features = 52
# number of features = 83
# number of features = 78
# number of features = 102
# number of features = 43
# number of features = 116
# number of features = 16
# number of features = 170
# number of features = 190
# number of features = 27
# number of features = 181
# number of features = 17
# number of features = 126
# number of features = 45
# number of features = 139
# number of features = 79
# number of features = 236
# number of features = 87
# number of features = 57
# number of features = 73
# number of features = 115
# number of features = 131
# number of features = 73
# number of features = 62
# number of features = 142
# batch 10 of 10 done

# %%
# pass in batches of 500
# MADHUKAR: 0 - 5000 
# SHOBHA: 5000 - 10000
# RADHIKA: 10000 - 15000

batch_size = 500
MY_NAME = "SHOBHA"
START = 0 + 5000 * (MY_NAME == "SHOBHA") + 10000 * (MY_NAME == "RADHIKA")

for batch in range(10):
  print("batch {} of 10 started".format(batch + 1))
  batch_df = df_m[START + batch_size * batch : START + batch_size * (batch + 1)].copy()
  extract_nwi_bbox_variables(batch_df, (START + batch_size * batch) + 1, size = PATCH_SIZE)
  print("batch {} of 10 done".format(batch + 1))
# Out:
# batch 1 of 10 started
# number of features = 7
# number of features = 80
# number of features = 93
# number of features = 88
# number of features = 124
# number of features = 34
# number of features = 187
# number of features = 130
# number of features = 142
# number of features = 114
# number of features = 74
# number of features = 93
# number of features = 116
# number of features = 100
# number of features = 128
# number of features = 213
# number of features = 47
# number of features = 22
# number of features = 77
# number of features = 457
# number of features = 78
# number of features = 60
# number of features = 40
# number of features = 78
# number of features = 223
# number of features = 18
# number of features = 31
# number of features = 378
# number of features = 19
# number of features = 40
# number of features = 121
# number of features = 142
# number of features = 63
# number of features = 28
# number of features = 40
# number of features = 39
# number of features = 73
# number of features = 172
# number of features = 102
# number of features = 56
# number of features = 14
# number of features = 94
# number of features = 202
# number of features = 84
# number of features = 2
# number of features = 44
# number of features = 176
# number of features = 121
# number of features = 109
# number of features = 59
# number of features = 93
# number of features = 103
# number of features = 39
# number of features = 94
# number of features = 51
# number of features = 29
# number of features = 99
# number of features = 9
# number of features = 14
# number of features = 70
# number of features = 69
# number of features = 116
# number of features = 166
# number of features = 105
# number of features = 42
# number of features = 165
# number of features = 108
# number of features = 83
# number of features = 31
# number of features = 89
# number of features = 31
# number of features = 75
# number of features = 39
# number of features = 129
# number of features = 43
# number of features = 70
# number of features = 147
# number of features = 54
# number of features = 124
# number of features = 32
# number of features = 61
# number of features = 134
# number of features = 113
# number of features = 106
# number of features = 48
# number of features = 272
# number of features = 43
# number of features = 157
# number of features = 57
# number of features = 42
# number of features = 37
# number of features = 45
# number of features = 126
# number of features = 104
# number of features = 60
# number of features = 38
# number of features = 52
# number of features = 65
# number of features = 88
# number of features = 116
# number of features = 66
# number of features = 53
# number of features = 53
# number of features = 58
# number of features = 76
# number of features = 105
# number of features = 62
# number of features = 135
# number of features = 63
# number of features = 93
# number of features = 251
# number of features = 35
# number of features = 70
# number of features = 21
# number of features = 134
# number of features = 42
# number of features = 67
# number of features = 51
# number of features = 123
# number of features = 29
# number of features = 107
# number of features = 77
# number of features = 59
# number of features = 95
# number of features = 45
# number of features = 22
# number of features = 69
# number of features = 25
# number of features = 191
# number of features = 33
# number of features = 137
# number of features = 120
# number of features = 32
# number of features = 25
# number of features = 72
# number of features = 37
# number of features = 20
# number of features = 107
# number of features = 89
# number of features = 45
# number of features = 82
# number of features = 162
# number of features = 77
# number of features = 78
# number of features = 225
# number of features = 38
# number of features = 54
# number of features = 46
# number of features = 11
# number of features = 108
# number of features = 113
# number of features = 38
# number of features = 59
# number of features = 76
# number of features = 19
# number of features = 68
# number of features = 62
# number of features = 47
# number of features = 96
# number of features = 104
# number of features = 73
# number of features = 97
# number of features = 66
# number of features = 41
# number of features = 43
# number of features = 44
# number of features = 111
# number of features = 78
# number of features = 73
# number of features = 94
# number of features = 55
# number of features = 79
# number of features = 153
# number of features = 76
# number of features = 171
# number of features = 45
# number of features = 55
# number of features = 142
# number of features = 55
# number of features = 42
# number of features = 49
# number of features = 18
# number of features = 72
# number of features = 49
# number of features = 23
# number of features = 47
# number of features = 72
# number of features = 22
# number of features = 46
# number of features = 43
# number of features = 78
# number of features = 90
# number of features = 53
# number of features = 54
# number of features = 36
# number of features = 14
# number of features = 132
# number of features = 59
# number of features = 111
# number of features = 106
# number of features = 39
# number of features = 100
# number of features = 94
# number of features = 56
# number of features = 53
# number of features = 52
# number of features = 87
# number of features = 56
# number of features = 19
# number of features = 204
# number of features = 41
# number of features = 20
# number of features = 55
# number of features = 72
# number of features = 60
# number of features = 103
# number of features = 99
# number of features = 110
# number of features = 31
# number of features = 78
# number of features = 84
# number of features = 27
# number of features = 110
# number of features = 11
# number of features = 50
# number of features = 28
# number of features = 71
# number of features = 105
# number of features = 91
# number of features = 35
# number of features = 17
# number of features = 82
# number of features = 26
# number of features = 18
# number of features = 94
# number of features = 52
# number of features = 57
# number of features = 41
# number of features = 164
# number of features = 37
# number of features = 31
# number of features = 158
# number of features = 37
# number of features = 115
# number of features = 48
# number of features = 121
# number of features = 166
# number of features = 78
# number of features = 54
# number of features = 32
# number of features = 88
# number of features = 79
# number of features = 258
# number of features = 102
# number of features = 55
# number of features = 109
# number of features = 44
# number of features = 39
# number of features = 35
# number of features = 160
# number of features = 24
# number of features = 52
# number of features = 77
# number of features = 51
# number of features = 156
# number of features = 37
# number of features = 111
# number of features = 23
# number of features = 66
# number of features = 37
# number of features = 25
# number of features = 58
# number of features = 21
# number of features = 91
# number of features = 63
# number of features = 40
# number of features = 51
# number of features = 77
# number of features = 66
# number of features = 46
# number of features = 61
# number of features = 35
# number of features = 54
# number of features = 49
# number of features = 20
# number of features = 112
# number of features = 92
# number of features = 109
# number of features = 157
# number of features = 75
# number of features = 59
# number of features = 36
# number of features = 53
# number of features = 87
# number of features = 106
# number of features = 39
# number of features = 128
# number of features = 50
# number of features = 50
# number of features = 78
# number of features = 64
# number of features = 85
# number of features = 40
# number of features = 49
# number of features = 77
# number of features = 80
# number of features = 105
# number of features = 129
# number of features = 35
# number of features = 170
# number of features = 72
# number of features = 46
# number of features = 103
# number of features = 83
# number of features = 78
# number of features = 60
# number of features = 43
# number of features = 61
# number of features = 23
# number of features = 37
# number of features = 49
# number of features = 154
# number of features = 136
# number of features = 116
# number of features = 59
# number of features = 59
# number of features = 62
# number of features = 40
# number of features = 116
# number of features = 24
# number of features = 67
# number of features = 85
# number of features = 66
# number of features = 218
# number of features = 16
# number of features = 55
# number of features = 142
# number of features = 54
# number of features = 94
# number of features = 60
# number of features = 58
# number of features = 72
# number of features = 52
# number of features = 40
# number of features = 149
# number of features = 57
# number of features = 97
# number of features = 57
# number of features = 44
# number of features = 72
# number of features = 25
# number of features = 120
# number of features = 63
# number of features = 75
# number of features = 32
# number of features = 44
# number of features = 78
# number of features = 21
# number of features = 43
# number of features = 38
# number of features = 242
# number of features = 8
# number of features = 74
# number of features = 64
# number of features = 60
# number of features = 23
# number of features = 60
# number of features = 72
# number of features = 44
# number of features = 153
# number of features = 55
# number of features = 165
# number of features = 40
# number of features = 109
# number of features = 70
# number of features = 87
# number of features = 60
# number of features = 85
# number of features = 138
# number of features = 46
# number of features = 47
# number of features = 134
# number of features = 47
# number of features = 80
# number of features = 196
# number of features = 204
# number of features = 14
# number of features = 77
# number of features = 102
# number of features = 200
# number of features = 68
# number of features = 57
# number of features = 93
# number of features = 46
# number of features = 37
# number of features = 246
# number of features = 33
# number of features = 91
# number of features = 82
# number of features = 37
# number of features = 83
# number of features = 56
# number of features = 81
# number of features = 93
# number of features = 190
# number of features = 88
# number of features = 7
# number of features = 56
# number of features = 88
# number of features = 74
# number of features = 78
# number of features = 124
# number of features = 141
# number of features = 68
# number of features = 17
# number of features = 43
# number of features = 32
# number of features = 182
# number of features = 55
# number of features = 31
# number of features = 51
# number of features = 209
# number of features = 113
# number of features = 60
# number of features = 99
# number of features = 66
# number of features = 215
# number of features = 71
# number of features = 37
# number of features = 228
# number of features = 72
# number of features = 38
# number of features = 135
# number of features = 38
# number of features = 31
# number of features = 69
# number of features = 72
# number of features = 63
# number of features = 94
# number of features = 41
# number of features = 98
# number of features = 196
# number of features = 25
# number of features = 28
# number of features = 78
# number of features = 53
# number of features = 73
# number of features = 70
# number of features = 56
# number of features = 36
# number of features = 66
# number of features = 52
# number of features = 62
# number of features = 133
# number of features = 35
# number of features = 14
# number of features = 157
# number of features = 92
# number of features = 69
# number of features = 66
# number of features = 126
# number of features = 126
# number of features = 49
# number of features = 36
# number of features = 17
# number of features = 58
# number of features = 64
# number of features = 65
# number of features = 76
# number of features = 39
# number of features = 63
# number of features = 96
# number of features = 60
# number of features = 138
# number of features = 42
# number of features = 83
# number of features = 46
# number of features = 89
# number of features = 61
# number of features = 81
# number of features = 76
# number of features = 76
# number of features = 104
# number of features = 19
# number of features = 123
# number of features = 140
# number of features = 79
# number of features = 99
# number of features = 93
# number of features = 42
# number of features = 238
# number of features = 95
# number of features = 28
# number of features = 28
# number of features = 164
# number of features = 100
# number of features = 32
# number of features = 97
# number of features = 48
# number of features = 34
# batch 1 of 10 done
# batch 2 of 10 started
# number of features = 344
# number of features = 80
# number of features = 105
# number of features = 154
# number of features = 112
# number of features = 34
# number of features = 18
# number of features = 65
# number of features = 44
# number of features = 38
# number of features = 71
# number of features = 57
# number of features = 90
# number of features = 42
# number of features = 71
# number of features = 113
# number of features = 35
# number of features = 71
# number of features = 61
# number of features = 340
# number of features = 7
# number of features = 83
# number of features = 30
# number of features = 129
# number of features = 93
# number of features = 28
# number of features = 72
# number of features = 75
# number of features = 48
# number of features = 146
# number of features = 176
# number of features = 33
# number of features = 51
# number of features = 44
# number of features = 89
# number of features = 49
# number of features = 33
# number of features = 0
# number of features = 82
# number of features = 47
# number of features = 0
# number of features = 31
# number of features = 12
# number of features = 144
# number of features = 46
# number of features = 60
# number of features = 19
# number of features = 26
# number of features = 20
# number of features = 53
# number of features = 17
# number of features = 43
# number of features = 6
# number of features = 11
# number of features = 91
# number of features = 37
# number of features = 112
# number of features = 14
# number of features = 65
# number of features = 16
# number of features = 72
# number of features = 11
# number of features = 70
# number of features = 0
# number of features = 65
# number of features = 47
# number of features = 57
# number of features = 19
# number of features = 25
# number of features = 34
# number of features = 34
# number of features = 22
# number of features = 12
# number of features = 0
# number of features = 0
# number of features = 25
# number of features = 0
# number of features = 102
# number of features = 24
# number of features = 34
# number of features = 8
# number of features = 62
# number of features = 10
# number of features = 36
# number of features = 12
# number of features = 23
# number of features = 35
# number of features = 40
# number of features = 14
# number of features = 19
# number of features = 11
# number of features = 118
# number of features = 96
# number of features = 49
# number of features = 49
# number of features = 4
# number of features = 74
# number of features = 0
# number of features = 6
# number of features = 92
# number of features = 23
# number of features = 30
# number of features = 26
# number of features = 7
# number of features = 12
# number of features = 20
# number of features = 3
# number of features = 30
# number of features = 118
# number of features = 34
# number of features = 32
# number of features = 62
# number of features = 20
# number of features = 3
# number of features = 45
# number of features = 31
# number of features = 0
# number of features = 34
# number of features = 18
# number of features = 0
# number of features = 81
# number of features = 23
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 23
# number of features = 32
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 29
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 24
# number of features = 0
# number of features = 34
# number of features = 20
# number of features = 25
# number of features = 30
# number of features = 27
# number of features = 17
# number of features = 0
# number of features = 13
# number of features = 32
# number of features = 24
# number of features = 25
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 37
# number of features = 0
# number of features = 0
# number of features = 3
# number of features = 0
# number of features = 0
# number of features = 17
# number of features = 25
# number of features = 20
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 43
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 23
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 111
# number of features = 0
# number of features = 17
# number of features = 43
# number of features = 9
# number of features = 13
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 23
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 20
# number of features = 111
# number of features = 0
# number of features = 41
# number of features = 23
# number of features = 0
# number of features = 34
# number of features = 48
# number of features = 49
# number of features = 53
# number of features = 14
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 31
# number of features = 31
# number of features = 0
# number of features = 0
# number of features = 21
# number of features = 5
# number of features = 0
# number of features = 17
# number of features = 76
# number of features = 13
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 10
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 27
# number of features = 0
# number of features = 9
# number of features = 16
# number of features = 0
# number of features = 28
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 31
# number of features = 3
# number of features = 4
# number of features = 49
# number of features = 7
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 43
# number of features = 0
# number of features = 0
# number of features = 108
# number of features = 31
# number of features = 27
# number of features = 95
# number of features = 10
# number of features = 3
# number of features = 24
# number of features = 133
# number of features = 36
# number of features = 78
# number of features = 232
# number of features = 100
# number of features = 50
# number of features = 63
# number of features = 44
# number of features = 34
# number of features = 64
# number of features = 77
# number of features = 82
# number of features = 87
# number of features = 102
# number of features = 28
# number of features = 115
# number of features = 43
# number of features = 59
# number of features = 44
# number of features = 82
# number of features = 174
# number of features = 92
# number of features = 0
# number of features = 37
# number of features = 89
# number of features = 24
# number of features = 32
# number of features = 99
# number of features = 0
# number of features = 64
# number of features = 0
# number of features = 0
# number of features = 111
# number of features = 36
# number of features = 0
# number of features = 33
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 60
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 22
# number of features = 85
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 139
# number of features = 145
# number of features = 153
# number of features = 0
# number of features = 0
# number of features = 91
# number of features = 0
# number of features = 102
# number of features = 0
# number of features = 0
# number of features = 36
# number of features = 0
# number of features = 63
# number of features = 46
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 43
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 50
# number of features = 0
# number of features = 0
# number of features = 97
# number of features = 0
# number of features = 73
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 8
# number of features = 38
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 95
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 53
# number of features = 87
# number of features = 103
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 5
# number of features = 75
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 1
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 52
# number of features = 0
# number of features = 44
# number of features = 0
# number of features = 13
# number of features = 30
# number of features = 0
# number of features = 0
# number of features = 168
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 52
# number of features = 0
# number of features = 127
# number of features = 0
# number of features = 0
# number of features = 23
# number of features = 0
# number of features = 87
# number of features = 10
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 5
# number of features = 0
# number of features = 0
# number of features = 113
# number of features = 66
# number of features = 0
# number of features = 141
# number of features = 53
# number of features = 19
# number of features = 31
# number of features = 84
# number of features = 134
# number of features = 34
# number of features = 43
# number of features = 15
# number of features = 61
# number of features = 16
# number of features = 92
# number of features = 42
# number of features = 76
# number of features = 20
# number of features = 35
# number of features = 85
# number of features = 50
# number of features = 55
# number of features = 100
# number of features = 104
# number of features = 71
# number of features = 24
# number of features = 4
# number of features = 81
# number of features = 70
# number of features = 35
# number of features = 62
# number of features = 11
# number of features = 39
# number of features = 27
# number of features = 48
# number of features = 47
# number of features = 39
# number of features = 87
# number of features = 23
# number of features = 30
# number of features = 114
# number of features = 90
# number of features = 32
# number of features = 12
# number of features = 89
# number of features = 40
# number of features = 103
# number of features = 26
# number of features = 46
# number of features = 109
# number of features = 2
# number of features = 64
# number of features = 25
# batch 2 of 10 done
# batch 3 of 10 started
# number of features = 19
# number of features = 78
# number of features = 55
# number of features = 90
# number of features = 38
# number of features = 37
# number of features = 88
# number of features = 54
# number of features = 51
# number of features = 52
# number of features = 55
# number of features = 59
# number of features = 47
# number of features = 51
# number of features = 32
# number of features = 64
# number of features = 52
# number of features = 38
# number of features = 66
# number of features = 89
# number of features = 36
# number of features = 34
# number of features = 47
# number of features = 59
# number of features = 110
# number of features = 85
# number of features = 73
# number of features = 23
# number of features = 21
# number of features = 20
# number of features = 94
# number of features = 86
# number of features = 36
# number of features = 51
# number of features = 51
# number of features = 107
# number of features = 72
# number of features = 56
# number of features = 54
# number of features = 84
# number of features = 74
# number of features = 10
# number of features = 44
# number of features = 89
# number of features = 52
# number of features = 74
# number of features = 36
# number of features = 50
# number of features = 33
# number of features = 10
# number of features = 22
# number of features = 9
# number of features = 23
# number of features = 13
# number of features = 22
# number of features = 127
# number of features = 22
# number of features = 15
# number of features = 21
# number of features = 12
# number of features = 61
# number of features = 42
# number of features = 24
# number of features = 36
# number of features = 57
# number of features = 48
# number of features = 24
# number of features = 87
# number of features = 10
# number of features = 40
# number of features = 43
# number of features = 72
# number of features = 20
# number of features = 26
# number of features = 38
# number of features = 35
# number of features = 29
# number of features = 59
# number of features = 8
# number of features = 141
# number of features = 65
# number of features = 97
# number of features = 60
# number of features = 20
# number of features = 16
# number of features = 24
# number of features = 28
# number of features = 24
# number of features = 10
# number of features = 62
# number of features = 65
# number of features = 112
# number of features = 148
# number of features = 53
# number of features = 18
# number of features = 26
# number of features = 29
# number of features = 155
# number of features = 36
# number of features = 89
# number of features = 56
# number of features = 28
# number of features = 24
# number of features = 93
# number of features = 47
# number of features = 9
# number of features = 38
# number of features = 30
# number of features = 96
# number of features = 39
# number of features = 42
# number of features = 38
# number of features = 6
# number of features = 151
# number of features = 52
# number of features = 27
# number of features = 34
# number of features = 73
# number of features = 30
# number of features = 63
# number of features = 22
# number of features = 85
# number of features = 65
# number of features = 108
# number of features = 15
# number of features = 19
# number of features = 69
# number of features = 23
# number of features = 27
# number of features = 40
# number of features = 29
# number of features = 26
# number of features = 34
# number of features = 43
# number of features = 52
# number of features = 49
# number of features = 40
# number of features = 52
# number of features = 37
# number of features = 53
# number of features = 56
# number of features = 33
# number of features = 36
# number of features = 41
# number of features = 28
# number of features = 29
# number of features = 55
# number of features = 53
# number of features = 54
# number of features = 52
# number of features = 48
# number of features = 17
# number of features = 31
# number of features = 10
# number of features = 45
# number of features = 7
# number of features = 53
# number of features = 97
# number of features = 54
# number of features = 64
# number of features = 53
# number of features = 37
# number of features = 19
# number of features = 82
# number of features = 51
# number of features = 54
# number of features = 64
# number of features = 53
# number of features = 52
# number of features = 8
# number of features = 29
# number of features = 46
# number of features = 97
# number of features = 106
# number of features = 52
# number of features = 39
# number of features = 119
# number of features = 72
# number of features = 101
# number of features = 130
# number of features = 30
# number of features = 87
# number of features = 10
# number of features = 104
# number of features = 108
# number of features = 28
# number of features = 32
# number of features = 40
# number of features = 67
# number of features = 11
# number of features = 37
# number of features = 23
# number of features = 49
# number of features = 52
# number of features = 93
# number of features = 100
# number of features = 56
# number of features = 100
# number of features = 58
# number of features = 53
# number of features = 91
# number of features = 46
# number of features = 50
# number of features = 64
# number of features = 76
# number of features = 213
# number of features = 53
# number of features = 101
# number of features = 9
# number of features = 24
# number of features = 71
# number of features = 56
# number of features = 53
# number of features = 52
# number of features = 49
# number of features = 12
# number of features = 49
# number of features = 91
# number of features = 83
# number of features = 83
# number of features = 54
# number of features = 13
# number of features = 103
# number of features = 25
# number of features = 34
# number of features = 22
# number of features = 22
# number of features = 55
# number of features = 20
# number of features = 245
# number of features = 64
# number of features = 59
# number of features = 45
# number of features = 96
# number of features = 44
# number of features = 34
# number of features = 73
# number of features = 74
# number of features = 79
# number of features = 45
# number of features = 41
# number of features = 54
# number of features = 53
# number of features = 54
# number of features = 33
# number of features = 58
# number of features = 53
# number of features = 55
# number of features = 51
# number of features = 55
# number of features = 39
# number of features = 56
# number of features = 33
# number of features = 31
# number of features = 53
# number of features = 35
# number of features = 94
# number of features = 44
# number of features = 63
# number of features = 52
# number of features = 20
# number of features = 8
# number of features = 50
# number of features = 36
# number of features = 99
# number of features = 247
# number of features = 58
# number of features = 90
# number of features = 54
# number of features = 81
# number of features = 75
# number of features = 40
# number of features = 26
# number of features = 42
# number of features = 68
# number of features = 78
# number of features = 98
# number of features = 38
# number of features = 35
# number of features = 28
# number of features = 36
# number of features = 51
# number of features = 115
# number of features = 21
# number of features = 86
# number of features = 33
# number of features = 35
# number of features = 14
# number of features = 30
# number of features = 40
# number of features = 24
# number of features = 70
# number of features = 47
# number of features = 92
# number of features = 48
# number of features = 55
# number of features = 61
# number of features = 20
# number of features = 20
# number of features = 31
# number of features = 48
# number of features = 84
# number of features = 34
# number of features = 81
# number of features = 109
# number of features = 48
# number of features = 114
# number of features = 55
# number of features = 70
# number of features = 37
# number of features = 31
# number of features = 25
# number of features = 159
# number of features = 73
# number of features = 116
# number of features = 114
# number of features = 94
# number of features = 62
# number of features = 31
# number of features = 86
# number of features = 45
# number of features = 101
# number of features = 31
# number of features = 55
# number of features = 72
# number of features = 32
# number of features = 11
# number of features = 5
# number of features = 79
# number of features = 57
# number of features = 1
# number of features = 50
# number of features = 40
# number of features = 59
# number of features = 24
# number of features = 56
# number of features = 55
# number of features = 91
# number of features = 71
# number of features = 179
# number of features = 6
# number of features = 40
# number of features = 12
# number of features = 46
# number of features = 28
# number of features = 70
# number of features = 11
# number of features = 47
# number of features = 85
# number of features = 90
# number of features = 28
# number of features = 47
# number of features = 79
# number of features = 32
# number of features = 51
# number of features = 53
# number of features = 62
# number of features = 91
# number of features = 56
# number of features = 41
# number of features = 196
# number of features = 137
# number of features = 90
# number of features = 28
# number of features = 48
# number of features = 86
# number of features = 98
# number of features = 16
# number of features = 117
# number of features = 58
# number of features = 51
# number of features = 83
# number of features = 99
# number of features = 94
# number of features = 57
# number of features = 108
# number of features = 43
# number of features = 28
# number of features = 41
# number of features = 45
# number of features = 8
# number of features = 56
# number of features = 39
# number of features = 51
# number of features = 41
# number of features = 88
# number of features = 16
# number of features = 34
# number of features = 64
# number of features = 82
# number of features = 34
# number of features = 99
# number of features = 102
# number of features = 56
# number of features = 72
# number of features = 27
# number of features = 125
# number of features = 6
# number of features = 49
# number of features = 70
# number of features = 15
# number of features = 33
# number of features = 98
# number of features = 24
# number of features = 59
# number of features = 2
# number of features = 39
# number of features = 67
# number of features = 32
# number of features = 88
# number of features = 72
# number of features = 117
# number of features = 36
# number of features = 33
# number of features = 85
# number of features = 46
# number of features = 82
# number of features = 116
# number of features = 27
# number of features = 83
# number of features = 66
# number of features = 31
# number of features = 29
# number of features = 63
# number of features = 66
# number of features = 44
# number of features = 37
# number of features = 31
# number of features = 94
# number of features = 15
# number of features = 36
# number of features = 18
# number of features = 40
# number of features = 25
# number of features = 86
# number of features = 37
# number of features = 10
# number of features = 31
# number of features = 93
# number of features = 54
# number of features = 23
# number of features = 162
# number of features = 62
# number of features = 89
# number of features = 22
# number of features = 57
# number of features = 16
# number of features = 9
# number of features = 70
# number of features = 55
# number of features = 48
# number of features = 31
# number of features = 65
# number of features = 48
# number of features = 25
# number of features = 69
# number of features = 127
# number of features = 9
# number of features = 39
# number of features = 65
# number of features = 73
# number of features = 35
# number of features = 26
# number of features = 40
# number of features = 46
# number of features = 14
# number of features = 43
# number of features = 61
# number of features = 11
# number of features = 175
# number of features = 33
# number of features = 24
# number of features = 47
# number of features = 10
# number of features = 32
# number of features = 31
# number of features = 34
# number of features = 10
# number of features = 61
# number of features = 51
# number of features = 53
# number of features = 95
# number of features = 52
# number of features = 16
# number of features = 50
# number of features = 43
# number of features = 56
# number of features = 58
# number of features = 50
# number of features = 33
# number of features = 28
# number of features = 85
# number of features = 155
# number of features = 25
# number of features = 29
# number of features = 30
# number of features = 35
# number of features = 43
# number of features = 59
# number of features = 42
# batch 3 of 10 done
# batch 4 of 10 started
# number of features = 6
# number of features = 63
# number of features = 15
# number of features = 34
# number of features = 127
# number of features = 27
# number of features = 52
# number of features = 58
# number of features = 42
# number of features = 92
# number of features = 44
# number of features = 7
# number of features = 92
# number of features = 53
# number of features = 50
# number of features = 49
# number of features = 72
# number of features = 38
# number of features = 82
# number of features = 25
# number of features = 40
# number of features = 34
# number of features = 45
# number of features = 6
# number of features = 28
# number of features = 49
# number of features = 90
# number of features = 46
# number of features = 22
# number of features = 44
# number of features = 25
# number of features = 58
# number of features = 70
# number of features = 18
# number of features = 56
# number of features = 51
# number of features = 27
# number of features = 27
# number of features = 39
# number of features = 23
# number of features = 60
# number of features = 36
# number of features = 54
# number of features = 64
# number of features = 33
# number of features = 15
# number of features = 24
# number of features = 34
# number of features = 81
# number of features = 43
# number of features = 31
# number of features = 62
# number of features = 5
# number of features = 40
# number of features = 29
# number of features = 28
# number of features = 12
# number of features = 22
# number of features = 20
# number of features = 49
# number of features = 7
# number of features = 13
# number of features = 54
# number of features = 39
# number of features = 84
# number of features = 43
# number of features = 56
# number of features = 85
# number of features = 55
# number of features = 134
# number of features = 57
# number of features = 35
# number of features = 46
# number of features = 22
# number of features = 135
# number of features = 104
# number of features = 26
# number of features = 66
# number of features = 96
# number of features = 57
# number of features = 72
# number of features = 25
# number of features = 122
# number of features = 25
# number of features = 2
# number of features = 29
# number of features = 117
# number of features = 278
# number of features = 72
# number of features = 47
# number of features = 292
# number of features = 42
# number of features = 38
# number of features = 85
# number of features = 18
# number of features = 13
# number of features = 2
# number of features = 39
# number of features = 38
# number of features = 17
# number of features = 38
# number of features = 24
# number of features = 22
# number of features = 11
# number of features = 62
# number of features = 64
# number of features = 39
# number of features = 236
# number of features = 80
# number of features = 90
# number of features = 6
# number of features = 44
# number of features = 10
# number of features = 38
# number of features = 73
# number of features = 20
# number of features = 47
# number of features = 44
# number of features = 27
# number of features = 17
# number of features = 40
# number of features = 42
# number of features = 43
# number of features = 27
# number of features = 45
# number of features = 20
# number of features = 35
# number of features = 43
# number of features = 12
# number of features = 38
# number of features = 51
# number of features = 50
# number of features = 47
# number of features = 48
# number of features = 48
# number of features = 39
# number of features = 59
# number of features = 88
# number of features = 18
# number of features = 30
# number of features = 19
# number of features = 42
# number of features = 21
# number of features = 15
# number of features = 54
# number of features = 26
# number of features = 9
# number of features = 37
# number of features = 87
# number of features = 54
# number of features = 46
# number of features = 39
# number of features = 38
# number of features = 31
# number of features = 88
# number of features = 80
# number of features = 36
# number of features = 40
# number of features = 88
# number of features = 43
# number of features = 21
# number of features = 10
# number of features = 25
# number of features = 34
# number of features = 5
# number of features = 84
# number of features = 7
# number of features = 16
# number of features = 43
# number of features = 27
# number of features = 45
# number of features = 17
# number of features = 46
# number of features = 28
# number of features = 39
# number of features = 71
# number of features = 52
# number of features = 66
# number of features = 16
# number of features = 29
# number of features = 32
# number of features = 66
# number of features = 34
# number of features = 42
# number of features = 20
# number of features = 63
# number of features = 60
# number of features = 36
# number of features = 46
# number of features = 28
# number of features = 82
# number of features = 28
# number of features = 88
# number of features = 65
# number of features = 25
# number of features = 22
# number of features = 32
# number of features = 30
# number of features = 25
# number of features = 28
# number of features = 9
# number of features = 67
# number of features = 54
# number of features = 41
# number of features = 106
# number of features = 57
# number of features = 30
# number of features = 49
# number of features = 18
# number of features = 4
# number of features = 18
# number of features = 16
# number of features = 84
# number of features = 52
# number of features = 41
# number of features = 55
# number of features = 15
# number of features = 47
# number of features = 25
# number of features = 22
# number of features = 85
# number of features = 104
# number of features = 39
# number of features = 48
# number of features = 28
# number of features = 41
# number of features = 45
# number of features = 38
# number of features = 49
# number of features = 36
# number of features = 40
# number of features = 24
# number of features = 41
# number of features = 31
# number of features = 33
# number of features = 16
# number of features = 50
# number of features = 37
# number of features = 36
# number of features = 35
# number of features = 9
# number of features = 40
# number of features = 59
# number of features = 20
# number of features = 18
# number of features = 26
# number of features = 18
# number of features = 68
# number of features = 46
# number of features = 18
# number of features = 40
# number of features = 44
# number of features = 34
# number of features = 13
# number of features = 44
# number of features = 79
# number of features = 23
# number of features = 31
# number of features = 72
# number of features = 89
# number of features = 48
# number of features = 12
# number of features = 46
# number of features = 85
# number of features = 14
# number of features = 20
# number of features = 45
# number of features = 97
# number of features = 16
# number of features = 24
# number of features = 147
# number of features = 106
# number of features = 44
# number of features = 35
# number of features = 36
# number of features = 41
# number of features = 62
# number of features = 19
# number of features = 8
# number of features = 44
# number of features = 19
# number of features = 43
# number of features = 43
# number of features = 60
# number of features = 69
# number of features = 11
# number of features = 113
# number of features = 19
# number of features = 39
# number of features = 58
# number of features = 41
# number of features = 44
# number of features = 51
# number of features = 47
# number of features = 4
# number of features = 44
# number of features = 56
# number of features = 41
# number of features = 52
# number of features = 27
# number of features = 11
# number of features = 21
# number of features = 17
# number of features = 69
# number of features = 74
# number of features = 56
# number of features = 68
# number of features = 20
# number of features = 76
# number of features = 39
# number of features = 10
# number of features = 7
# number of features = 59
# number of features = 49
# number of features = 59
# number of features = 64
# number of features = 20
# number of features = 77
# number of features = 72
# number of features = 42
# number of features = 83
# number of features = 58
# number of features = 62
# number of features = 123
# number of features = 59
# number of features = 66
# number of features = 88
# number of features = 128
# number of features = 81
# number of features = 75
# number of features = 20
# number of features = 22
# number of features = 76
# number of features = 22
# number of features = 31
# number of features = 27
# number of features = 37
# number of features = 32
# number of features = 26
# number of features = 10
# number of features = 40
# number of features = 47
# number of features = 57
# number of features = 24
# number of features = 72
# number of features = 39
# number of features = 32
# number of features = 54
# number of features = 54
# number of features = 45
# number of features = 71
# number of features = 30
# number of features = 16
# number of features = 81
# number of features = 30
# number of features = 28
# number of features = 74
# number of features = 103
# number of features = 71
# number of features = 138
# number of features = 24
# number of features = 18
# number of features = 64
# number of features = 55
# number of features = 45
# number of features = 125
# number of features = 20
# number of features = 15
# number of features = 35
# number of features = 18
# number of features = 23
# number of features = 4
# number of features = 37
# number of features = 75
# number of features = 94
# number of features = 45
# number of features = 55
# number of features = 10
# number of features = 88
# number of features = 35
# number of features = 56
# number of features = 18
# number of features = 73
# number of features = 27
# number of features = 142
# number of features = 99
# number of features = 21
# number of features = 31
# number of features = 86
# number of features = 60
# number of features = 80
# number of features = 86
# number of features = 94
# number of features = 26
# number of features = 108
# number of features = 90
# number of features = 7
# number of features = 29
# number of features = 86
# number of features = 49
# number of features = 51
# number of features = 43
# number of features = 73
# number of features = 65
# number of features = 49
# number of features = 8
# number of features = 44
# number of features = 49
# number of features = 31
# number of features = 92
# number of features = 63
# number of features = 38
# number of features = 36
# number of features = 72
# number of features = 63
# number of features = 27
# number of features = 34
# number of features = 56
# number of features = 35
# number of features = 14
# number of features = 57
# number of features = 46
# number of features = 45
# number of features = 55
# number of features = 30
# number of features = 18
# number of features = 15
# number of features = 53
# number of features = 25
# number of features = 37
# number of features = 31
# number of features = 5
# number of features = 86
# number of features = 64
# number of features = 117
# number of features = 126
# number of features = 0
# number of features = 0
# number of features = 51
# number of features = 68
# number of features = 158
# number of features = 76
# number of features = 50
# number of features = 20
# number of features = 3
# number of features = 41
# number of features = 0
# number of features = 15
# number of features = 16
# number of features = 31
# number of features = 171
# number of features = 114
# number of features = 27
# number of features = 23
# number of features = 23
# number of features = 190
# number of features = 42
# number of features = 79
# number of features = 0
# number of features = 49
# number of features = 35
# number of features = 104
# number of features = 96
# number of features = 47
# number of features = 58
# number of features = 0
# number of features = 0
# number of features = 32
# number of features = 0
# number of features = 93
# number of features = 0
# number of features = 0
# number of features = 30
# number of features = 0
# number of features = 49
# number of features = 69
# number of features = 192
# number of features = 87
# number of features = 17
# number of features = 182
# number of features = 68
# number of features = 40
# number of features = 38
# number of features = 38
# number of features = 17
# number of features = 30
# number of features = 149
# number of features = 20
# number of features = 112
# number of features = 84
# number of features = 16
# number of features = 0
# number of features = 36
# number of features = 110
# number of features = 15
# ...
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 85
# number of features = 112
# number of features = 81
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 73
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 10
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 64
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 68
# number of features = 0
# number of features = 6
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 107
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 60
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 102
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# batch 9 of 10 done
# batch 10 of 10 started
# number of features = 98
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 64
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 76
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 34
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 13
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 96
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 88
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 48
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 66
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 40
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 75
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 36
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 11
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 26
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 6
# number of features = 0
# number of features = 58
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 28
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 130
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 144
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 11
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 39
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 41
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 73
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 70
# number of features = 59
# number of features = 0
# number of features = 47
# number of features = 67
# number of features = 78
# number of features = 116
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 29
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 77
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 161
# number of features = 94
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 61
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 46
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# batch 10 of 10 done

# %%
# pass in batches of 500
# MADHUKAR: 0 - 5000 
# SHOBHA: 5000 - 10000
# RADHIKA: 10000 - 15000

batch_size = 500
MY_NAME = "RADHIKA"
START = 0 + 5000 * (MY_NAME == "SHOBHA") + 10000 * (MY_NAME == "RADHIKA")

for batch in range(10):
  print("batch {} of 10 started".format(batch + 1))
  batch_df = df_m[START + batch_size * batch : START + batch_size * (batch + 1)].copy()
  extract_nwi_bbox_variables(batch_df, (START + batch_size * batch) + 1, size = PATCH_SIZE)
  print("batch {} of 10 done".format(batch + 1))
# Out:
# batch 1 of 10 started
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 161
# number of features = 0
# number of features = 1
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 11
# number of features = 46
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 81
# number of features = 0
# number of features = 54
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 5
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 144
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 94
# number of features = 60
# number of features = 120
# number of features = 61
# number of features = 89
# number of features = 66
# number of features = 192
# number of features = 22
# number of features = 103
# number of features = 219
# number of features = 49
# number of features = 123
# number of features = 37
# number of features = 73
# number of features = 69
# number of features = 44
# number of features = 42
# number of features = 114
# number of features = 98
# number of features = 41
# number of features = 54
# number of features = 100
# number of features = 112
# number of features = 83
# number of features = 44
# number of features = 38
# number of features = 112
# number of features = 90
# number of features = 48
# number of features = 41
# number of features = 95
# number of features = 126
# number of features = 67
# number of features = 116
# number of features = 112
# number of features = 91
# number of features = 0
# number of features = 65
# number of features = 83
# number of features = 185
# number of features = 93
# number of features = 41
# number of features = 76
# number of features = 27
# number of features = 73
# number of features = 14
# number of features = 0
# number of features = 36
# number of features = 0
# number of features = 0
# number of features = 70
# number of features = 39
# number of features = 16
# number of features = 19
# number of features = 98
# number of features = 72
# number of features = 24
# number of features = 78
# number of features = 19
# number of features = 88
# number of features = 55
# number of features = 81
# number of features = 8
# number of features = 30
# number of features = 110
# number of features = 129
# number of features = 89
# number of features = 0
# number of features = 0
# number of features = 0
# number of features = 41
# number of features = 49
# number of features = 181
# number of features = 49
# number of features = 94
# number of features = 79
# number of features = 41
# number of features = 130
# number of features = 86
# number of features = 39
# number of features = 199
# number of features = 79
# number of features = 107
# number of features = 45
# number of features = 38
# number of features = 86
# number of features = 26
# number of features = 95
# number of features = 84
# number of features = 74
# number of features = 74
# number of features = 17
# number of features = 130
# number of features = 29
# number of features = 45
# number of features = 18
# number of features = 15
# number of features = 20
# number of features = 109
# number of features = 13
# number of features = 27
# number of features = 118
# number of features = 50
# number of features = 154
# number of features = 35
# number of features = 30
# number of features = 29
# number of features = 32
# number of features = 27
# number of features = 8
# number of features = 52
# number of features = 14
# number of features = 39
# number of features = 7
# number of features = 35
# number of features = 104
# number of features = 43
# number of features = 29
# number of features = 45
# number of features = 17
# number of features = 29
# number of features = 102
# number of features = 74
# number of features = 45
# number of features = 52
# number of features = 37
# number of features = 62
# number of features = 54
# number of features = 102
# number of features = 25
# number of features = 39
# number of features = 24
# number of features = 19
# number of features = 35
# number of features = 15
# number of features = 34
# number of features = 34
# number of features = 92
# number of features = 39
# number of features = 90
# number of features = 89
# number of features = 47
# number of features = 31
# number of features = 84
# number of features = 18
# number of features = 41
# number of features = 43
# number of features = 44
# number of features = 44
# number of features = 6
# number of features = 57
# number of features = 1
# number of features = 21
# number of features = 88
# number of features = 29
# number of features = 16
# number of features = 208
# number of features = 41
# number of features = 49
# number of features = 9
# number of features = 51
# number of features = 16
# number of features = 44
# number of features = 22
# number of features = 81
# number of features = 117
# number of features = 89
# number of features = 23
# number of features = 65
# number of features = 138
# number of features = 48
# number of features = 6
# number of features = 38
# number of features = 23
# number of features = 56
# number of features = 68
# number of features = 156
# number of features = 36
# number of features = 23
# number of features = 16
# number of features = 74
# number of features = 50
# number of features = 51
# number of features = 112
# number of features = 14
# number of features = 24
# number of features = 30
# number of features = 29
# number of features = 74
# number of features = 106
# number of features = 106
# number of features = 56
# number of features = 98
# number of features = 21
# number of features = 10
# number of features = 10
# number of features = 35
# number of features = 0
# number of features = 28
# number of features = 83
# number of features = 75
# number of features = 12
# number of features = 59
# number of features = 13
# number of features = 38
# number of features = 77
# number of features = 107
# number of features = 8
# number of features = 41
# number of features = 18
# number of features = 4
# number of features = 101
# number of features = 64
# number of features = 21
# number of features = 26
# number of features = 24
# number of features = 13
# number of features = 28
# number of features = 15
# number of features = 79
# number of features = 20
# number of features = 14
# number of features = 35
# number of features = 25
# number of features = 16
# number of features = 100
# number of features = 16
# number of features = 16
# number of features = 79
# number of features = 102
# number of features = 62
# number of features = 29
# number of features = 34
# number of features = 33
# number of features = 27
# number of features = 45
# number of features = 32
# number of features = 41
# number of features = 59
# number of features = 30
# number of features = 21
# number of features = 28
# number of features = 37
# number of features = 23
# number of features = 45
# number of features = 27
# number of features = 27
# number of features = 48
# number of features = 28
# number of features = 33
# number of features = 37
# number of features = 35
# number of features = 87
# number of features = 2
# number of features = 97
# number of features = 8
# number of features = 30
# number of features = 85
# number of features = 36
# number of features = 97
# number of features = 43
# number of features = 46
# number of features = 97
# number of features = 15
# number of features = 31
# number of features = 26
# number of features = 49
# number of features = 55
# number of features = 28
# number of features = 69
# number of features = 31
# number of features = 27
# number of features = 65
# number of features = 66
# number of features = 43
# number of features = 52
# number of features = 44
# number of features = 58
# number of features = 58
# number of features = 67
# number of features = 65
# number of features = 32
# number of features = 70
# number of features = 31
# number of features = 47
# number of features = 50
# number of features = 51
# number of features = 25
# number of features = 45
# number of features = 44
# number of features = 54
# number of features = 15
# number of features = 27
# number of features = 30
# number of features = 24
# number of features = 26
# number of features = 33
# number of features = 22
# number of features = 37
# number of features = 16
# number of features = 65
# number of features = 9
# number of features = 10
# number of features = 128
# number of features = 72
# number of features = 20
# number of features = 35
# number of features = 26
# number of features = 35
# number of features = 23
# number of features = 134
# number of features = 33
# number of features = 19
# number of features = 3
# number of features = 13
# number of features = 18
# number of features = 47
# number of features = 1
# number of features = 25
# number of features = 55
# number of features = 52
# number of features = 54
# number of features = 50
# number of features = 39
# number of features = 94
# number of features = 37
# number of features = 37
# number of features = 43
# number of features = 48
# number of features = 20
# number of features = 38
# number of features = 62
# number of features = 36
# number of features = 20
# number of features = 24
# number of features = 47
# number of features = 36
# number of features = 15
# number of features = 14
# number of features = 75
# number of features = 74
# number of features = 75
# number of features = 41
# number of features = 58
# number of features = 97
# number of features = 74
# number of features = 51
# number of features = 15
# number of features = 29
# number of features = 32
# number of features = 30
# number of features = 59
# number of features = 58
# number of features = 77
# number of features = 22
# number of features = 26
# number of features = 14
# number of features = 40
# number of features = 63
# number of features = 50
# number of features = 57
# number of features = 20
# number of features = 4
# number of features = 63
# number of features = 132
# number of features = 33
# number of features = 26
# number of features = 73
# number of features = 74
# batch 1 of 10 done
# batch 2 of 10 started
# number of features = 32
# number of features = 23
# number of features = 15
# number of features = 40
# number of features = 48
# number of features = 57
# number of features = 8
# number of features = 67
# number of features = 114
# number of features = 46
# number of features = 20
# number of features = 64
# number of features = 32
# number of features = 75
# number of features = 25
# number of features = 20
# number of features = 23
# number of features = 18
# number of features = 53
# number of features = 23
# number of features = 28
# number of features = 42
# number of features = 22
# number of features = 20
# number of features = 34
# number of features = 33
# number of features = 28
# number of features = 38
# number of features = 37
# number of features = 40
# number of features = 33
# number of features = 19
# number of features = 20
# number of features = 54
# number of features = 17
# number of features = 78
# number of features = 17
# number of features = 65
# number of features = 64
# number of features = 26
# number of features = 27
# number of features = 66
# number of features = 62
# number of features = 17
# number of features = 52
# number of features = 93
# number of features = 20
# number of features = 48
# number of features = 21
# number of features = 49
# number of features = 45
# number of features = 74
# number of features = 39
# number of features = 9
# number of features = 41
# number of features = 73
# number of features = 26
# number of features = 40
# number of features = 14
# number of features = 55
# number of features = 9
# number of features = 36
# number of features = 87
# number of features = 26
# number of features = 66
# number of features = 201
# number of features = 20
# number of features = 79
# number of features = 35
# number of features = 33
# number of features = 33
# number of features = 20
# number of features = 71
# number of features = 41
# number of features = 31
# number of features = 6
# number of features = 30
# number of features = 21
# number of features = 41
# number of features = 37
# number of features = 36
# number of features = 42
# number of features = 106
# number of features = 26
# number of features = 31
# number of features = 32
# number of features = 15
# number of features = 41
# number of features = 28
# number of features = 7
# number of features = 68
# number of features = 76
# number of features = 35
# number of features = 50
# number of features = 39
# number of features = 36
# number of features = 20
# number of features = 12
# number of features = 27
# number of features = 8
# number of features = 18
# number of features = 26
# number of features = 31
# number of features = 45
# number of features = 38
# number of features = 71
# number of features = 27
# number of features = 83
# number of features = 59
# number of features = 40
# number of features = 63
# number of features = 29
# number of features = 55
# number of features = 38
# number of features = 15
# number of features = 12
# number of features = 8
# number of features = 16
# number of features = 26
# number of features = 15
# number of features = 16
# number of features = 39
# number of features = 32
# number of features = 46
# number of features = 101
# number of features = 33
# number of features = 33
# number of features = 2
# number of features = 31
# number of features = 67
# number of features = 30
# number of features = 74
# number of features = 18
# number of features = 16
# number of features = 38
# number of features = 25
# number of features = 46
# number of features = 34
# number of features = 29
# number of features = 63
# number of features = 17
# number of features = 20
# number of features = 18
# number of features = 60
# number of features = 62
# number of features = 46
# number of features = 80
# number of features = 29
# number of features = 24
# number of features = 31
# number of features = 34
# number of features = 23
# number of features = 16
# number of features = 32
# number of features = 34
# number of features = 50
# number of features = 84
# number of features = 62
# number of features = 7
# number of features = 73
# number of features = 81
# number of features = 97
# number of features = 43
# number of features = 63
# number of features = 45
# number of features = 45
# number of features = 24
# number of features = 51
# number of features = 35
# number of features = 37
# number of features = 17
# number of features = 62
# number of features = 53
# number of features = 61
# number of features = 33
# number of features = 13
# number of features = 30
# number of features = 78
# number of features = 42
# number of features = 37
# number of features = 15
# number of features = 42
# number of features = 34
# number of features = 48
# number of features = 35
# number of features = 56
# number of features = 44
# number of features = 44
# number of features = 33
# number of features = 34
# number of features = 11
# number of features = 20
# number of features = 27
# number of features = 28
# number of features = 41
# number of features = 28
# number of features = 25
# number of features = 27
# number of features = 24
# number of features = 36
# number of features = 66
# number of features = 76
# number of features = 29
# number of features = 44
# number of features = 25
# number of features = 32
# number of features = 98
# number of features = 48
# number of features = 26
# number of features = 26
# number of features = 75
# number of features = 28
# number of features = 33
# number of features = 46
# number of features = 8
# number of features = 40
# number of features = 39
# number of features = 7
# number of features = 54
# number of features = 84
# number of features = 58
# number of features = 52
# number of features = 14
# number of features = 30
# number of features = 51
# number of features = 23
# number of features = 47
# number of features = 10
# number of features = 5
# number of features = 17
# number of features = 43
# number of features = 21
# number of features = 77
# number of features = 17
# number of features = 72
# number of features = 57
# number of features = 28
# number of features = 30
# number of features = 51
# number of features = 30
# number of features = 38
# number of features = 27
# number of features = 19
# number of features = 36
# number of features = 42
# number of features = 78
# number of features = 29
# number of features = 47
# number of features = 37
# number of features = 9
# number of features = 24
# number of features = 7
# number of features = 84
# number of features = 45
# number of features = 73
# number of features = 6
# number of features = 65
# number of features = 43
# number of features = 90
# number of features = 75
# number of features = 19
# number of features = 72
# number of features = 13
# number of features = 58
# number of features = 86
# number of features = 40
# number of features = 41
# number of features = 53
# number of features = 51
# number of features = 32
# number of features = 61
# number of features = 19
# number of features = 50
# number of features = 86
# number of features = 21
# number of features = 54
# number of features = 44
# number of features = 22
# number of features = 72
# number of features = 40
# number of features = 20
# number of features = 40
# number of features = 19
# number of features = 68
# number of features = 39
# number of features = 11
# number of features = 12
# number of features = 68
# number of features = 93
# number of features = 106
# number of features = 77
# number of features = 116
# number of features = 81
# number of features = 16
# number of features = 108
# number of features = 80
# number of features = 70
# number of features = 68
# number of features = 84
# number of features = 71
# number of features = 92
# number of features = 48
# number of features = 74
# number of features = 91
# number of features = 19
# number of features = 55
# number of features = 57
# number of features = 88
# number of features = 96
# number of features = 89
# number of features = 67
# number of features = 111
# number of features = 57
# number of features = 58
# number of features = 94
# number of features = 40
# number of features = 69
# number of features = 55
# number of features = 18
# number of features = 47
# number of features = 37
# number of features = 43
# number of features = 24
# number of features = 48
# number of features = 59
# number of features = 126
# number of features = 63
# number of features = 87
# number of features = 98
# number of features = 44
# number of features = 79
# number of features = 91
# number of features = 83
# number of features = 61
# number of features = 94
# number of features = 50
# number of features = 32
# number of features = 15
# number of features = 59
# number of features = 63
# number of features = 55
# number of features = 89
# number of features = 96
# number of features = 83
# number of features = 83
# number of features = 152
# number of features = 162
# number of features = 92
# number of features = 92
# number of features = 69
# number of features = 41
# number of features = 57
# number of features = 71
# number of features = 100
# number of features = 117
# number of features = 41
# number of features = 71
# number of features = 28
# number of features = 76
# number of features = 94
# number of features = 51
# number of features = 78
# number of features = 63
# number of features = 36
# number of features = 38
# number of features = 30
# number of features = 55
# number of features = 56
# number of features = 65
# number of features = 53
# number of features = 57
# number of features = 10
# number of features = 79
# number of features = 31
# number of features = 15
# number of features = 33
# number of features = 17
# number of features = 57
# number of features = 25
# number of features = 48
# number of features = 39
# number of features = 78
# number of features = 60
# number of features = 32
# number of features = 56
# number of features = 76
# number of features = 45
# number of features = 94
# number of features = 57
# number of features = 80
# number of features = 84
# number of features = 71
# number of features = 59
# number of features = 94
# number of features = 19
# number of features = 57
# number of features = 97
# number of features = 33
# number of features = 86
# number of features = 87
# number of features = 53
# number of features = 56
# number of features = 72
# number of features = 36
# number of features = 32
# number of features = 57
# number of features = 40
# number of features = 20
# number of features = 45
# number of features = 101
# number of features = 44
# number of features = 91
# number of features = 2
# number of features = 74
# number of features = 39
# number of features = 54
# number of features = 104
# number of features = 30
# number of features = 55
# number of features = 59
# number of features = 68
# number of features = 53
# number of features = 11
# number of features = 24
# number of features = 12
# number of features = 33
# number of features = 19
# number of features = 41
# number of features = 34
# number of features = 94
# number of features = 122
# number of features = 39
# number of features = 73
# number of features = 61
# number of features = 52
# number of features = 37
# number of features = 32
# number of features = 43
# number of features = 35
# number of features = 14
# number of features = 44
# number of features = 64
# number of features = 51
# number of features = 27
# number of features = 58
# number of features = 21
# number of features = 35
# number of features = 56
# number of features = 100
# number of features = 52
# number of features = 14
# number of features = 58
# number of features = 17
# number of features = 45
# number of features = 52
# number of features = 13
# number of features = 36
# number of features = 81
# number of features = 39
# number of features = 68
# number of features = 74
# number of features = 28
# number of features = 25
# number of features = 36
# number of features = 52
# number of features = 34
# number of features = 58
# number of features = 49
# number of features = 25
# number of features = 41
# number of features = 35
# number of features = 26
# number of features = 36
# number of features = 35
# number of features = 71
# number of features = 35
# number of features = 49
# number of features = 64
# number of features = 34
# number of features = 55
# number of features = 9
# number of features = 53
# number of features = 49
# number of features = 14
# number of features = 51
# number of features = 105
# number of features = 34
# number of features = 31
# number of features = 41
# number of features = 42
# number of features = 51
# number of features = 41
# number of features = 18
# number of features = 34
# number of features = 50
# number of features = 50
# number of features = 17
# number of features = 27
# number of features = 36
# number of features = 33
# batch 2 of 10 done
# batch 3 of 10 started
# number of features = 30
# number of features = 33
# number of features = 27
# number of features = 42
# number of features = 103
# number of features = 44
# number of features = 35
# number of features = 24
# number of features = 28
# number of features = 25
# number of features = 32
# number of features = 39
# number of features = 73
# number of features = 38
# number of features = 56
# number of features = 112
# number of features = 34
# number of features = 15
# number of features = 29
# number of features = 31
# number of features = 28
# number of features = 27
# number of features = 126
# number of features = 45
# number of features = 19
# number of features = 38
# number of features = 13
# number of features = 15
# number of features = 23
# number of features = 108
# number of features = 12
# number of features = 43
# number of features = 64
# number of features = 50
# number of features = 73
# number of features = 191
# number of features = 66
# number of features = 97
# number of features = 54
# number of features = 47
# number of features = 64
# number of features = 60
# number of features = 30
# number of features = 14
# number of features = 13
# number of features = 22
# number of features = 48
# number of features = 78
# number of features = 73
# number of features = 26
# number of features = 72
# number of features = 88
# number of features = 72
# number of features = 17
# number of features = 34
# number of features = 47
# number of features = 49
# number of features = 29
# number of features = 25
# number of features = 62
# number of features = 97
# number of features = 102
# number of features = 91
# number of features = 92
# number of features = 42
# number of features = 38
# number of features = 42
# number of features = 26
# number of features = 123
# number of features = 28
# number of features = 40
# number of features = 79
# number of features = 24
# number of features = 18
# number of features = 41
# number of features = 16
# number of features = 28
# number of features = 23
# number of features = 106
# number of features = 52
# number of features = 95
# number of features = 19
# number of features = 24
# number of features = 21
# number of features = 30
# number of features = 17
# number of features = 18
# number of features = 61
# number of features = 39
# number of features = 25
# number of features = 80
# number of features = 63
# number of features = 40
# number of features = 4
# number of features = 13
# number of features = 43
# number of features = 50
# number of features = 19
# number of features = 28
# number of features = 27
# number of features = 25
# number of features = 34
# number of features = 9
# number of features = 8
# number of features = 12
# number of features = 10
# number of features = 6
# number of features = 3
# number of features = 92
# number of features = 13
# number of features = 127
# number of features = 98
# number of features = 23
# number of features = 53
# number of features = 25
# number of features = 2
# number of features = 107
# number of features = 103
# number of features = 75
# number of features = 74
# number of features = 27
# number of features = 82
# number of features = 115
# number of features = 43
# number of features = 15
# number of features = 3
# number of features = 42
# number of features = 28
# number of features = 19
# number of features = 20
# number of features = 42
# number of features = 45
# number of features = 18
# number of features = 45
# number of features = 54
# number of features = 32
# number of features = 13
# number of features = 20
# number of features = 58
# number of features = 62
# number of features = 43
# number of features = 116
# number of features = 37
# number of features = 28
# number of features = 18
# number of features = 2
# number of features = 4
# number of features = 49
# number of features = 2
# number of features = 41
# number of features = 46
# number of features = 25
# number of features = 16
# number of features = 4
# number of features = 13
# number of features = 15
# number of features = 57
# number of features = 19
# number of features = 58
# number of features = 41
# number of features = 42
# number of features = 16
# number of features = 25
# number of features = 28
# number of features = 45
# number of features = 9
# number of features = 13
# number of features = 78
# number of features = 18
# number of features = 47
# number of features = 1
# number of features = 18
# number of features = 58
# number of features = 34
# number of features = 95
# number of features = 68
# number of features = 66
# number of features = 42
# number of features = 36
# number of features = 28
# number of features = 52
# number of features = 67
# number of features = 39
# number of features = 73
# number of features = 53
# number of features = 93
# number of features = 81
# number of features = 21
# number of features = 22
# number of features = 24
# number of features = 63
# number of features = 77
# number of features = 55
# number of features = 133
# number of features = 7
# number of features = 54
# number of features = 16
# number of features = 20
# number of features = 15
# number of features = 3
# number of features = 10
# number of features = 7
# number of features = 140
# number of features = 27
# number of features = 16
# number of features = 26
# number of features = 18
# number of features = 8
# number of features = 26
# number of features = 42
# number of features = 79
# number of features = 52
# number of features = 32
# number of features = 47
# number of features = 71
# number of features = 58
# number of features = 68
# number of features = 41
# number of features = 65
# number of features = 91
# number of features = 22
# number of features = 2
# number of features = 23
# number of features = 27
# number of features = 27
# number of features = 26
# number of features = 26
# number of features = 31
# number of features = 16
# number of features = 11
# number of features = 4
# number of features = 7
# number of features = 12
# number of features = 26
# number of features = 5
# number of features = 29
# number of features = 47
# number of features = 46
# number of features = 18
# number of features = 3
# number of features = 43
# number of features = 43
# number of features = 38
# number of features = 44
# number of features = 14
# number of features = 34
# number of features = 25
# number of features = 66
# number of features = 34
# number of features = 37
# number of features = 33
# number of features = 22
# number of features = 42
# number of features = 55
# number of features = 5
# number of features = 25
# number of features = 45
# number of features = 15
# number of features = 151
# number of features = 7
# number of features = 25
# number of features = 37
# number of features = 78
# number of features = 58
# number of features = 81
# number of features = 92
# number of features = 54
# number of features = 68
# number of features = 36
# number of features = 14
# number of features = 18
# number of features = 28
# number of features = 40
# number of features = 13
# number of features = 78
# number of features = 26
# number of features = 42
# number of features = 39
# number of features = 32
# number of features = 46
# number of features = 26
# number of features = 34
# number of features = 34
# number of features = 54
# number of features = 70
# number of features = 67
# number of features = 69
# number of features = 34
# number of features = 48
# number of features = 46
# number of features = 77
# number of features = 56
# number of features = 99
# number of features = 32
# number of features = 34
# number of features = 40
# number of features = 110
# number of features = 26
# number of features = 45
# number of features = 57
# number of features = 31
# number of features = 16
# number of features = 32
# number of features = 18
# number of features = 11
# number of features = 11
# number of features = 8
# number of features = 3
# number of features = 13
# number of features = 16
# number of features = 92
# number of features = 24
# number of features = 67
# number of features = 41
# number of features = 15
# number of features = 50
# number of features = 13
# number of features = 51
# number of features = 86
# number of features = 62
# number of features = 28
# number of features = 20
# number of features = 13
# number of features = 37
# number of features = 96
# number of features = 13
# number of features = 10
# number of features = 23
# number of features = 14
# number of features = 4
# number of features = 14
# number of features = 27
# number of features = 51
# number of features = 28
# number of features = 37
# number of features = 4
# number of features = 3
# number of features = 30
# number of features = 7
# number of features = 64
# number of features = 20
# number of features = 13
# number of features = 109
# number of features = 73
# number of features = 14
# number of features = 19
# number of features = 19
# number of features = 36
# number of features = 45
# number of features = 39
# number of features = 42
# number of features = 44
# number of features = 94
# number of features = 43
# number of features = 58
# number of features = 53
# number of features = 94
# number of features = 38
# number of features = 35
# number of features = 33
# number of features = 14
# number of features = 9
# number of features = 36
# number of features = 21
# number of features = 32
# number of features = 17
# number of features = 9
# number of features = 1
# number of features = 57
# number of features = 16
# number of features = 4
# number of features = 1
# number of features = 7
# number of features = 7
# number of features = 13
# number of features = 6
# number of features = 41
# number of features = 39
# number of features = 43
# number of features = 83
# number of features = 17
# number of features = 84
# number of features = 5
# number of features = 8
# number of features = 55
# number of features = 26
# number of features = 42
# number of features = 30
# number of features = 28
# number of features = 15
# number of features = 48
# number of features = 35
# number of features = 11
# number of features = 80
# number of features = 29
# number of features = 18
# number of features = 26
# number of features = 38
# number of features = 13
# number of features = 36
# number of features = 13
# number of features = 64
# number of features = 7
# number of features = 38
# number of features = 4
# number of features = 48
# number of features = 17
# number of features = 52
# number of features = 37
# number of features = 37
# number of features = 22
# number of features = 2
# number of features = 34
# number of features = 27
# number of features = 30
# number of features = 60
# number of features = 47
# number of features = 42
# number of features = 9
# number of features = 43
# number of features = 72
# number of features = 46
# number of features = 30
# number of features = 59
# number of features = 60
# number of features = 82
# number of features = 18
# number of features = 29
# number of features = 107
# number of features = 2
# number of features = 19
# number of features = 12
# number of features = 7
# number of features = 76
# number of features = 61
# number of features = 84
# number of features = 29
# number of features = 39
# number of features = 61
# number of features = 19
# number of features = 33
# number of features = 11
# number of features = 14
# number of features = 28
# number of features = 122
# number of features = 31
# number of features = 54
# number of features = 36
# number of features = 28
# number of features = 41
# number of features = 6
# number of features = 12
# number of features = 4
# number of features = 10
# number of features = 127
# number of features = 67
# number of features = 21
# number of features = 38
# number of features = 55
# number of features = 51
# number of features = 75
# number of features = 64
# number of features = 29
# number of features = 114
# number of features = 37
# number of features = 121
# number of features = 71
# number of features = 137
# number of features = 60
# number of features = 32
# number of features = 68
# number of features = 40
# number of features = 23
# number of features = 67
# number of features = 36
# number of features = 54
# number of features = 16
# number of features = 23
# number of features = 8
# number of features = 49
# number of features = 62
# number of features = 69
# number of features = 22
# number of features = 53
# number of features = 61
# number of features = 60
# number of features = 18
# number of features = 86
# number of features = 40
# number of features = 68
# number of features = 11
# number of features = 69
# number of features = 3
# number of features = 32
# number of features = 41
# number of features = 27
# number of features = 15
# number of features = 54
# number of features = 32
# number of features = 8
# batch 3 of 10 done
# batch 4 of 10 started
# number of features = 7
# number of features = 32
# number of features = 58
# number of features = 9
# number of features = 25
# number of features = 30
# number of features = 14
# number of features = 113
# number of features = 51
# number of features = 71
# number of features = 37
# number of features = 37
# number of features = 42
# number of features = 102
# number of features = 3
# number of features = 101
# number of features = 5
# number of features = 13
# number of features = 72
# number of features = 54
# number of features = 93
# number of features = 124
# number of features = 10
# number of features = 59
# number of features = 94
# number of features = 36
# number of features = 69
# number of features = 20
# number of features = 16
# number of features = 22
# number of features = 21
# number of features = 15
# number of features = 10
# number of features = 6
# number of features = 21
# number of features = 35
# number of features = 4
# number of features = 7
# number of features = 105
# number of features = 13
# number of features = 28
# number of features = 51
# number of features = 76
# number of features = 14
# number of features = 30
# number of features = 11
# number of features = 15
# number of features = 6
# number of features = 18
# number of features = 8
# number of features = 10
# number of features = 24
# number of features = 37
# number of features = 66
# number of features = 23
# number of features = 70
# number of features = 0
# number of features = 96
# number of features = 63
# number of features = 15
# number of features = 34
# number of features = 19
# number of features = 22
# number of features = 5
# number of features = 33
# number of features = 8
# number of features = 31
# number of features = 43
# number of features = 9
# number of features = 55
# number of features = 25
# number of features = 50
# number of features = 63
# number of features = 85
# number of features = 33
# number of features = 30
# number of features = 51
# number of features = 119
# number of features = 67
# number of features = 64
# number of features = 110
# number of features = 103
# number of features = 68
# number of features = 45
# number of features = 62
# number of features = 196
# number of features = 41
# number of features = 91
# number of features = 60
# number of features = 44
# number of features = 37
# number of features = 30
# number of features = 119
# number of features = 36
# number of features = 14
# number of features = 56
# number of features = 14
# number of features = 35
# number of features = 43
# number of features = 21
# number of features = 36
# number of features = 47
# number of features = 56
# number of features = 26
# number of features = 46
# number of features = 53
# number of features = 141
# number of features = 154
# number of features = 43
# number of features = 25
# number of features = 143
# number of features = 55
# number of features = 56
# number of features = 48
# number of features = 23
# number of features = 56
# number of features = 18
# number of features = 15
# number of features = 40
# number of features = 62
# number of features = 72
# number of features = 31
# number of features = 19
# number of features = 1
# number of features = 16
# number of features = 114
# number of features = 53
# number of features = 43
# number of features = 41
# number of features = 32
# number of features = 53
# number of features = 60
# number of features = 63
# number of features = 163
# number of features = 31
# number of features = 136
# number of features = 31
# number of features = 68
# number of features = 43
# number of features = 69
# number of features = 43
# number of features = 15
# number of features = 20
# number of features = 60
# number of features = 19
# number of features = 32
# number of features = 28
# number of features = 54
# number of features = 31
# number of features = 36
# number of features = 19
# number of features = 84
# number of features = 64
# number of features = 39
# number of features = 38
# number of features = 38
# number of features = 45
# number of features = 88
# number of features = 31
# number of features = 95
# number of features = 24
# number of features = 35
# number of features = 74
# number of features = 60
# number of features = 123
# number of features = 54
# number of features = 41
# number of features = 53
# number of features = 60
# number of features = 31
# number of features = 33
# number of features = 42
# number of features = 65
# number of features = 28
# number of features = 61
# number of features = 135
# number of features = 125
# number of features = 37
# number of features = 51
# number of features = 45
# number of features = 21
# number of features = 64
# number of features = 77
# number of features = 29
# number of features = 58
# number of features = 54
# number of features = 140
# number of features = 69
# number of features = 37
# number of features = 73
# number of features = 56
# number of features = 56
# number of features = 102
# number of features = 60
# number of features = 41
# number of features = 45
# number of features = 44
# number of features = 41
# number of features = 25
# number of features = 92
# number of features = 80
# number of features = 81
# number of features = 50
# number of features = 84
# number of features = 69
# number of features = 18
# number of features = 36
# number of features = 50
# number of features = 94
# number of features = 63
# number of features = 61
# number of features = 31
# number of features = 75
# number of features = 38
# number of features = 83
# number of features = 106
# number of features = 38
# number of features = 19
# number of features = 15
# number of features = 100
# number of features = 112
# number of features = 77
# number of features = 21
# number of features = 84
# number of features = 32
# number of features = 63
# number of features = 69
# number of features = 57
# number of features = 30
# number of features = 46
# number of features = 29
# number of features = 35
# number of features = 33
# number of features = 31
# number of features = 29
# number of features = 62
# number of features = 16
# number of features = 21
# number of features = 75
# number of features = 133
# number of features = 37
# number of features = 72
# number of features = 91
# number of features = 53
# number of features = 40
# number of features = 48
# number of features = 47
# number of features = 47
# number of features = 88
# number of features = 37
# number of features = 56
# number of features = 31
# number of features = 18
# number of features = 61
# number of features = 41
# number of features = 107
# number of features = 34
# number of features = 58
# number of features = 115
# number of features = 82
# number of features = 53
# number of features = 63
# number of features = 101
# number of features = 26
# number of features = 93
# number of features = 51
# number of features = 74
# number of features = 107
# number of features = 71
# number of features = 62
# number of features = 40
# number of features = 38
# number of features = 59
# number of features = 46
# number of features = 75
# number of features = 41
# number of features = 21
# number of features = 110
# number of features = 76
# number of features = 81
# number of features = 36
# number of features = 15
# number of features = 20
# number of features = 42
# number of features = 70
# number of features = 39
# number of features = 50
# number of features = 108
# number of features = 66
# number of features = 44
# number of features = 47
# number of features = 67
# number of features = 21
# number of features = 34
# number of features = 24
# number of features = 23
# number of features = 60
# number of features = 14
# number of features = 47
# number of features = 48
# number of features = 61
# number of features = 52
# number of features = 31
# number of features = 67
# number of features = 174
# number of features = 57
# number of features = 41
# number of features = 66
# number of features = 35
# number of features = 35
# number of features = 28
# number of features = 45
# number of features = 5
# number of features = 36
# number of features = 131
# number of features = 33
# number of features = 93
# number of features = 27
# number of features = 27
# number of features = 22
# number of features = 5
# number of features = 98
# number of features = 27
# number of features = 105
# number of features = 21
# number of features = 21
# number of features = 37
# number of features = 96
# number of features = 59
# number of features = 26
# number of features = 81
# number of features = 59
# number of features = 46
# number of features = 25
# number of features = 32
# number of features = 21
# number of features = 62
# number of features = 38
# number of features = 40
# number of features = 27
# number of features = 22
# number of features = 24
# number of features = 60
# number of features = 35
# number of features = 35
# number of features = 94
# number of features = 34
# number of features = 19
# number of features = 115
# number of features = 39
# number of features = 62
# number of features = 24
# number of features = 122
# number of features = 15
# number of features = 41
# number of features = 42
# number of features = 43
# number of features = 81
# number of features = 50
# number of features = 38
# number of features = 150
# number of features = 13
# number of features = 124
# number of features = 36
# number of features = 85
# number of features = 55
# number of features = 58
# number of features = 67
# number of features = 97
# number of features = 25
# number of features = 32
# number of features = 75
# number of features = 47
# number of features = 27
# number of features = 19
# number of features = 86
# number of features = 37
# number of features = 35
# number of features = 64
# number of features = 47
# number of features = 11
# number of features = 30
# number of features = 91
# number of features = 34
# number of features = 92
# number of features = 38
# number of features = 42
# number of features = 25
# number of features = 24
# number of features = 10
# number of features = 59
# number of features = 122
# number of features = 141
# number of features = 68
# number of features = 47
# number of features = 12
# number of features = 73
# number of features = 53
# number of features = 27
# number of features = 8
# number of features = 42
# number of features = 76
# number of features = 59
# number of features = 45
# number of features = 72
# number of features = 55
# number of features = 112
# number of features = 38
# number of features = 15
# number of features = 69
# number of features = 32
# number of features = 46
# number of features = 145
# number of features = 49
# number of features = 53
# number of features = 36
# number of features = 40
# number of features = 45
# number of features = 16
# number of features = 48
# number of features = 49
# number of features = 30
# number of features = 15
# number of features = 41
# number of features = 36
# number of features = 42
# number of features = 50
# number of features = 45
# number of features = 40
# number of features = 53
# number of features = 47
# number of features = 23
# number of features = 26
# number of features = 71
# number of features = 67
# number of features = 77
# number of features = 25
# number of features = 53
# number of features = 74
# number of features = 72
# number of features = 51
# number of features = 14
# number of features = 44
# number of features = 32
# number of features = 51
# number of features = 42
# number of features = 55
# number of features = 27
# number of features = 93
# number of features = 37
# number of features = 57
# number of features = 28
# number of features = 121
# number of features = 16
# number of features = 42
# number of features = 34
# number of features = 22
# number of features = 37
# number of features = 29
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-785d2a75b14e> in <module>
#      11   print("batch {} of 10 started".format(batch + 1))
#      12   batch_df = df_m[START + batch_size * batch : START + batch_size * (batch + 1)].copy()
# ---> 13   extract_nwi_bbox_variables(batch_df, (START + batch_size * batch) + 1, size = PATCH_SIZE)
#      14   print("batch {} of 10 done".format(batch + 1))
#
# <ipython-input-10-6c16ab535a25> in extract_nwi_bbox_variables(df_m_, i, size)
#       1 def extract_nwi_bbox_variables(df_m_, i, size):
#       2
# ----> 3   df_m_["nwi_bbox_vars_" + str(2 * PATCH_SIZE) + "m"] = (df_m_.apply(lambda x:
#       4                                                      nwi_bbox_features(lat=x.latitude,
#       5                                                                        lon=x.longitude,
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
#    7767     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-10-6c16ab535a25> in <lambda>(x)
#       2
#       3   df_m_["nwi_bbox_vars_" + str(2 * PATCH_SIZE) + "m"] = (df_m_.apply(lambda x:
# ----> 4                                                      nwi_bbox_features(lat=x.latitude,
#       5                                                                        lon=x.longitude,
#       6                                                                        size=size), axis=1))
#
# <ipython-input-8-e597f07f21bf> in nwi_bbox_features(lat, lon, size)
#       8     """
#       9     try:
# ---> 10         fc_getInfo = fc.filterBounds(square(lat, lon, size)).getInfo()
#      11         fc_getInfo = fc_getInfo.get('features')
#      12         num_of_features = len(fc_getInfo)
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/ee/collection.py in getInfo(self)
#     125            properties.
#     126     """
# --> 127     return super(Collection, self).getInfo()
#     128
#     129   def limit(self, maximum, opt_property=None, opt_ascending=None):
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/ee/computedobject.py in getInfo(self)
#      96       The object can evaluate to anything.
#      97     """
# ---> 98     return data.computeValue(self)
#      99
#     100   def encode(self, encoder):
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/ee/data.py in computeValue(obj)
#     672     The result of evaluating that object on the server.
#     673   """
# --> 674   return _execute_cloud_call(
#     675       _get_cloud_api_resource().projects().value().compute(
#     676           body={'expression': serializer.encode(obj, for_cloud_api=True)},
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     332   """
#     333   try:
# --> 334     return call.execute(num_retries=num_retries)
#     335   except googleapiclient.errors.HttpError as e:
#     336     raise _translate_cloud_exception(e)
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     898
#     899         # Handle retries for server-side errors.
# --> 900         resp, content = _retry_request(
#     901             http,
#     902             num_retries,
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/googleapiclient/http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     175         try:
#     176             exception = None
# --> 177             resp, content = http.request(uri, method, *args, **kwargs)
#     178         # Retry on SSL errors and socket timeout errors.
#     179         except _ssl_SSLError as ssl_error:
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/google_auth_httplib2.py in request(self, uri, method, body, headers, **kwargs)
#     198
#     199         # Make the request.
# --> 200         response, content = self.http.request(
#     201             uri, method, body=body, headers=request_headers, **kwargs)
#     202
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/httplib2/__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1706                     content = b""
#    1707                 else:
# -> 1708                     (response, content) = self._request(
#    1709                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1710                     )
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/httplib2/__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1422             auth.request(method, request_uri, headers, body)
#    1423
# -> 1424         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1425
#    1426         if auth:
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/site-packages/httplib2/__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1374                 pass
#    1375             try:
# -> 1376                 response = conn.getresponse()
#    1377             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1378                 # If we get a BadStatusLine on the first try then that means
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/miniconda3/envs/gee/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from datetime import datetime
print(datetime.now())

# %%
#read the file
# df_m_test = pd.read_csv('NHD_extracted_vars/combined_regular_clean_with_ssurgo_nhd_variables_part1.csv')
df_m_test = pd.read_pickle("NWI_extracted_vars_" + str(2 * PATCH_SIZE) + "m/nwi_extraction_" 
                           + str(2 * PATCH_SIZE) + "X" + str(2 * PATCH_SIZE) + "m"
                           + "_part1")

# %%
df_m_test["nwi_bbox_vars_" + str(2 * PATCH_SIZE) + "m"]

# %%
df_m_test.columns
